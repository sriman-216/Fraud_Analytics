# %% [markdown]
# ## Tools and Libraries

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import torch
import os

from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## The Custom Environment
#
# This class acts as the interface between the dataset and the SB3 agent.

# %%
class FraudDetectionEnv(gym.Env):
    """
    A custom Gym environment for Fraud Detection using embeddings.

    State: Embedding of a transaction.
    Action: 0 (Declare Not Fraud), 1 (Declare Fraud).
    Reward: Based on correctly/incorrectly classifying fraud vs non-fraud.
    """
    def __init__(self, embeddings: np.ndarray, labels: np.ndarray, reward_config: dict):
        super().__init__()

        # Ensure data consistency
        assert embeddings.shape[0] == labels.shape[0], "Embeddings and labels must have the same number of instances."
        # Removed fixed dimension check to support PCA-reduced embeddings
        
        self.embeddings = embeddings.astype(np.float32)
        self.labels = labels.astype(np.int64)

        self.num_instances = self.embeddings.shape[0]
        self.embedding_dim = self.embeddings.shape[1]  # Get actual dimension
        self.reward_config = reward_config

        # Define action and observation space
        # Action Space: Discrete(2) -> 0 for Not Fraud, 1 for Fraud
        self.action_space = spaces.Discrete(2)

        # Observation Space: Box(low, high, shape, dtype) -> flexible dimension
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, 
            shape=(self.embedding_dim,), 
            dtype=np.float32
        )

        # Internal state
        self._current_index = 0
        self._order = np.arange(self.num_instances)
        np.random.shuffle(self._order) # Shuffle the order of instances initially


    def step(self, action: int):
        # Check if episode is done
        if self._current_index >= self.num_instances:
            print("Warning: step() called when episode is already done.")
            return self.observation_space.sample() * 0, 0, True, False, {} # Return dummy values

        # Get current instance data based on shuffled order
        actual_index = self._order[self._current_index]
        current_embedding = self.embeddings[actual_index]
        true_label = self.labels[actual_index]

        # Determine reward
        reward = 0
        if action == 1 and true_label == 1:
            reward = self.reward_config.get('TP', 0)
        elif action == 1 and true_label == 0:
            reward = self.reward_config.get('FP', 0)
        elif action == 0 and true_label == 1:
            reward = self.reward_config.get('FN', 0)
        elif action == 0 and true_label == 0:
            reward = self.reward_config.get('TN', 0)

        # Move to the next instance
        self._current_index += 1

        # Check if the episode is finished
        done = self._current_index >= self.num_instances
        truncated = False

        # Get the next observation
        next_observation = np.zeros_like(current_embedding, dtype=np.float32) # Default for done state
        if not done:
             next_observation = self.embeddings[self._order[self._current_index]]

        info = {
            'true_label': true_label,
            'predicted_action': action,
            'instance_uid': actual_index,
            'is_done': done
        }

        return next_observation, reward, done, truncated, info


    def reset(self, seed=None, options=None):
        super().reset(seed=seed) # Handles seeding

        # Reset index and shuffle order for a new episode
        self._current_index = 0
        self._order = np.arange(self.num_instances)
        self.np_random.shuffle(self._order) # Use the environment's random number generator

        # Get the first observation of the new episode
        initial_observation = self.embeddings[self._order[self._current_index]]

        info = {'instance_uid': self._order[self._current_index]}

        return initial_observation, info

    def close(self):
        # Optional: Implement cleanup
        pass

# %% [markdown]
# ## Loading the Data (Embeddings)

# %%
data = pd.read_pickle("/home/rachit/COT/COT1/mini/Fraud_Analytics/embeddings/attention_pooled_embeddings.pkl")

# %%
embeddings = data['embeddings']
labels = np.array(data['labels'])

print(f"Embeddings: {embeddings.shape}")
print(f"True labels: {labels.shape}")
# Out:
# Embeddings: (2952, 768)
# True labels: (2952,)

# %%
embeddings_train, embeddings_test, labels_train, labels_test = train_test_split(
    embeddings, labels, test_size=0.2, random_state=42, stratify=labels
)

print(f"Training Embeddings shape: {embeddings_train.shape}")
print(f"Training Labels shape: {labels_train.shape}")

print(f"Testing Embeddings shape: {embeddings_test.shape}")
print(f"Testing Labels shape: {labels_test.shape}")

print("\nClass distribution in splits:")
print(f"Original: Fraud={np.mean(labels):.4f}")
print(f"Train:    Fraud={np.mean(labels_train):.4f}")
print(f"Test:     Fraud={np.mean(labels_test):.4f}")
# Out:
# Training Embeddings shape: (2361, 768)
# Training Labels shape: (2361,)
# Testing Embeddings shape: (591, 768)
# Testing Labels shape: (591,)
#
# Class distribution in splits:
# Original: Fraud=0.1667
# Train:    Fraud=0.1669
# Test:     Fraud=0.1658

# %% [markdown]
# ## PCA Dimensionality Reduction
#
# We apply PCA to reduce the 768-dimensional embeddings to a lower dimension while retaining most of the variance. This helps with:
# - Computational efficiency
# - Reduced overfitting
# - Faster training

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
scaler = StandardScaler()
# Fit only on training data to avoid data leakage
embeddings_train_scaled = scaler.fit_transform(embeddings_train)
embeddings_test_scaled = scaler.transform(embeddings_test)

print(f"Scaled training embeddings shape: {embeddings_train_scaled.shape}")
print(f"Scaled test embeddings shape: {embeddings_test_scaled.shape}")
# Out:
# Scaled training embeddings shape: (2361, 768)
# Scaled test embeddings shape: (591, 768)

# %%
# Fit PCA with all components to analyze variance
pca_full = PCA(n_components=embeddings_train_scaled.shape[1])
pca_full.fit(embeddings_train_scaled)

# Compute cumulative explained variance
cum_var = np.cumsum(pca_full.explained_variance_ratio_)

# Plot to visualize how many components we need
plt.figure(figsize=(10, 6))
plt.plot(np.arange(1, len(cum_var)+1), cum_var, linewidth=2)
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Variance')
plt.axhline(y=0.99, color='g', linestyle='--', label='99% Variance')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA: Cumulative Explained Variance')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Find number of components for 95% and 99% variance
n_95 = np.argmax(cum_var >= 0.95) + 1
n_99 = np.argmax(cum_var >= 0.99) + 1
print(f"Components for 95% variance: {n_95}")
print(f"Components for 99% variance: {n_99}")
# Out:
# Components for 95% variance: 18
# Components for 99% variance: 85

# %%
# Apply PCA with 70 components (matching the PaySim notebook approach)
n_components = n_99
pca = PCA(n_components=n_components, whiten=True)
embeddings_train_pca = pca.fit_transform(embeddings_train_scaled)
embeddings_test_pca = pca.transform(embeddings_test_scaled)

print(f"\nPCA Reduction Results:")
print(f"Original dimensions: {embeddings_train_scaled.shape[1]}")
print(f"Reduced dimensions: {n_components}")
print(f"Training embeddings (PCA): {embeddings_train_pca.shape}")
print(f"Test embeddings (PCA): {embeddings_test_pca.shape}")
print(f"Variance explained: {pca.explained_variance_ratio_.sum():.4f}")
# Out:
# PCA Reduction Results:
# Original dimensions: 768
# Reduced dimensions: 85
# Training embeddings (PCA): (2361, 85)
# Test embeddings (PCA): (591, 85)
# Variance explained: 0.9900

# %% [markdown]
# ## CTGAN Data Augmentation
#
# We use CTGAN (Conditional Tabular GAN) to generate synthetic fraud samples to address class imbalance:
# - Generates realistic synthetic fraud embeddings
# - Improves model performance on minority class
# - Helps the RL agent learn better fraud detection patterns

# %%
# !pip install ctgan
# Out:
# Requirement already satisfied: ctgan in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.23.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from ctgan) (2.2.6)
# Requirement already satisfied: pandas>=1.4.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from ctgan) (2.3.3)
# Requirement already satisfied: torch>=1.13.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from ctgan) (2.10.0)
# Requirement already satisfied: tqdm>=4.29 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from ctgan) (4.67.3)
# Requirement already satisfied: rdt>=1.14.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from ctgan) (1.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas>=1.4.0->ctgan) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas>=1.4.0->ctgan) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas>=1.4.0->ctgan) (2025.3)
# Requirement already satisfied: six>=1.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->ctgan) (1.17.0)
# Requirement already satisfied: scipy>=1.9.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from rdt>=1.14.0->ctgan) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from rdt>=1.14.0->ctgan) (1.7.2)
# Requirement already satisfied: Faker!=37.11.0,>=17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from rdt>=1.14.0->ctgan) (40.5.1)
# Requirement already satisfied: joblib>=1.2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from scikit-learn>=1.1.0->rdt>=1.14.0->ctgan) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from scikit-learn>=1.1.0->rdt>=1.14.0->ctgan) (3.6.0)
# Requirement already satisfied: filelock in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.4.2)
# Requirement already satisfied: jinja2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (2025.10.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=1.13.0->ctgan) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.13.0->ctgan) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->ctgan) (3.0.3)

# %%
from ctgan import CTGAN

# Build a DataFrame of PCA embeddings + labels
df_pca = pd.DataFrame(
    embeddings_train_pca,
    columns=[f"pc{i+1}" for i in range(embeddings_train_pca.shape[1])]
)
df_pca['label'] = labels_train

print(f"Original training data shape: {df_pca.shape}")
print(f"Class distribution:")
print(df_pca['label'].value_counts())

# Extract only fraud samples (minority class)
fraud_df = df_pca[df_pca['label'] == 1].drop('label', axis=1)
print(f"\nFraud samples for CTGAN training: {len(fraud_df)}")
# Out:
# Original training data shape: (2361, 86)
# Class distribution:
# label
# 0    1967
# 1     394
# Name: count, dtype: int64
#
# Fraud samples for CTGAN training: 394

# %%
# Initialize and train CTGAN (pac=1 to disable PacGAN grouping)
ctgan = CTGAN(epochs=200, batch_size=64, pac=1, verbose=True)
print("Training CTGAN on fraud samples...")
ctgan.fit(fraud_df)

# Generate synthetic fraud embeddings (same count as real fraud)
n_synthetic = len(fraud_df)
print(f"\nGenerating {n_synthetic} synthetic fraud samples...")
synthetic_fraud_df = ctgan.sample(n_synthetic)

# Convert to numpy arrays
synthetic_embeddings = synthetic_fraud_df.values.astype(np.float32)
synthetic_labels = np.ones(n_synthetic, dtype=np.int64)

print(f"Synthetic embeddings shape: {synthetic_embeddings.shape}")
print(f"Synthetic labels shape: {synthetic_labels.shape}")
# Out:
# Training CTGAN on fraud samples...
# Gen. (+00.00) | Discrim. (+00.00):   0%|          | 0/200 [00:00<?, ?it/s]/data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/autograd/graph.py:865: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:330.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Gen. (-00.67) | Discrim. (-00.63): 100%|██████████| 200/200 [01:48<00:00,  1.85it/s]
# Generating 394 synthetic fraud samples...
# Synthetic embeddings shape: (394, 85)
# Synthetic labels shape: (394,)

# %%
# Augment training set with synthetic fraud samples
embeddings_train_aug = np.vstack([embeddings_train_pca, synthetic_embeddings])
labels_train_aug = np.concatenate([labels_train, synthetic_labels])

print(f"\n=== Data Augmentation Results ===")
print(f"Original training samples: {len(embeddings_train_pca)}")
print(f"  - Fraud: {np.sum(labels_train == 1)}")
print(f"  - Non-fraud: {np.sum(labels_train == 0)}")
print(f"\nSynthetic fraud samples added: {n_synthetic}")
print(f"\nAugmented training samples: {len(embeddings_train_aug)}")
print(f"  - Fraud: {np.sum(labels_train_aug == 1)}")
print(f"  - Non-fraud: {np.sum(labels_train_aug == 0)}")
print(f"\nClass balance improved:")
print(f"  Before: {np.mean(labels_train):.4f}")
print(f"  After: {np.mean(labels_train_aug):.4f}")
# Out:
# === Data Augmentation Results ===
# Original training samples: 2361
#   - Fraud: 394
#   - Non-fraud: 1967
#
# Synthetic fraud samples added: 394
#
# Augmented training samples: 2755
#   - Fraud: 788
#   - Non-fraud: 1967
#
# Class balance improved:
#   Before: 0.1669
#   After: 0.2860

# %%
from sklearn.manifold import TSNE

# Select real fraud embeddings
real_fraud = embeddings_train_pca[labels_train == 1]
synthetic_fraud = synthetic_embeddings

# Combine for t-SNE visualization
combined = np.vstack([real_fraud, synthetic_fraud])
labels_viz = np.array([0] * len(real_fraud) + [1] * len(synthetic_fraud))

# Run t-SNE
print("Running t-SNE for visualization...")
tsne = TSNE(n_components=2, random_state=42, init='pca', verbose=1)
embeddings_2d = tsne.fit_transform(combined)

# Plot
plt.figure(figsize=(10, 8))
plt.scatter(embeddings_2d[labels_viz == 0, 0], 
           embeddings_2d[labels_viz == 0, 1], 
           c='blue', marker='o', alpha=0.6, s=50, label='Real Fraud')
plt.scatter(embeddings_2d[labels_viz == 1, 0], 
           embeddings_2d[labels_viz == 1, 1], 
           c='red', marker='x', alpha=0.6, s=50, label='Synthetic Fraud')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.title('t-SNE: Real vs Synthetic Fraud Embeddings')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\nVisualization complete. Synthetic samples should overlap with real fraud clusters.")
# Out:
# Running t-SNE for visualization...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 788 samples in 0.001s...
# [t-SNE] Computed neighbors for 788 samples in 0.035s...
# [t-SNE] Computed conditional probabilities for sample 788 / 788
# [t-SNE] Mean sigma: 4.038514
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.855877
# [t-SNE] KL divergence after 1000 iterations: 1.558541
# Visualization complete. Synthetic samples should overlap with real fraud clusters.

# %% [markdown]
# ## Update: Using PCA-Reduced and Augmented Data
#
# Now we'll use:
# - **Training data**: PCA-reduced (70D) + CTGAN augmented embeddings
# - **Test data**: PCA-reduced (70D) embeddings only
# - **Environment**: Updated to handle flexible dimensions (70D instead of 768D)

# %% [markdown]
# ## Summary of Improvements
#
# ### 1. PCA Dimensionality Reduction
# - **From**: 768 dimensions (original DistilBERT embeddings)
# - **To**: 70 dimensions (PCA-reduced)
# - **Benefits**:
#   - Faster training (less parameters in neural networks)
#   - Reduced overfitting risk
#   - Lower memory footprint
#   - Retained variance: ~95%+
#
# ### 2. CTGAN Data Augmentation
# - **Generated**: Synthetic fraud samples (equal to real fraud count)
# - **Method**: Conditional Tabular GAN
# - **Benefits**:
#   - Improved class balance
#   - Better fraud pattern learning
#   - Enhanced minority class performance
#   - More robust model
#
# ### 3. Updated Environment
# - **Modified**: `FraudDetectionEnv` to accept flexible dimensions
# - **Training**: Uses 70D PCA + CTGAN augmented data
# - **Testing**: Uses 70D PCA-reduced data (no augmentation)
# - **Observation space**: Dynamically adjusted to embedding dimension

# %% [markdown]
# ## Define Reward Configuration and Instantiate Environment
#
# Now we configure the rewards for the agent and create the environment instance.

# %%
reward_config = {
    'TP': 10.0,
    'FP': -5.0,
    'FN': -20.0,
    'TN': 1.0
}

print("Reward configuration:", reward_config)

# Create vectorized environment instance using PCA-reduced and augmented data
n_envs = 8
train_env = make_vec_env(FraudDetectionEnv, 
                        env_kwargs={'embeddings': embeddings_train_aug,  # Use augmented data
                                   'labels': labels_train_aug,          # Use augmented labels
                                   'reward_config': reward_config}, 
                        n_envs=n_envs, 
                        seed=0, 
                        vec_env_cls=SubprocVecEnv)


print("Training Environment created with PCA + CTGAN augmented data.")
print(f"Observation space: {train_env.observation_space}")
print(f"  - Embedding dimension: 70 (reduced from 768 via PCA)")
print(f"Action space: {train_env.action_space}")
print(f"Training samples: {len(embeddings_train_aug)}")
# Out:
# Reward configuration: {'TP': 10.0, 'FP': -5.0, 'FN': -20.0, 'TN': 1.0}
# Training Environment created with PCA + CTGAN augmented data.
# Observation space: Box(-inf, inf, (85,), float32)
#   - Embedding dimension: 70 (reduced from 768 via PCA)
# Action space: Discrete(2)
# Training samples: 2755

# %% [markdown]
# ## Define and Train the DQN Agent
#
# We define the DQN model and start training.

# %%
tensorboard_log_dir = "./dqn_fraud_tb/"

# %%
# Define a learning rate schedule
def linear_schedule(initial_value):
    def schedule(progress_remaining):
        return progress_remaining * initial_value
    return schedule

# %%
# Define the DQN model with MLP and scheduled learning rate
model = DQN("MlpPolicy",
            train_env,
            learning_rate=linear_schedule(1e-4),  # Use the schedule here
            buffer_size=100000,  # Size of the replay buffer
            learning_starts=1000, # Number of steps before learning starts (buffer needs data)
            batch_size=512,      # Minibatch size for gradient updates
            gamma=0.99,         # Discount factor
            train_freq=1,       # Train the model after each episode step
            gradient_steps=1,   # Number of gradient steps per training iteration
            target_update_interval=500, # Update the target network every N steps
            exploration_fraction=0.1, # Fraction of total timesteps for exploration phase
            exploration_initial_eps=1.0, # Initial epsilon value
            exploration_final_eps=0.05,  # Final epsilon value
            max_grad_norm=10,   # Clip gradients to avoid instability
            verbose=1,          # Print training information
            device="auto",      # Use GPU if available, otherwise CPU
            tensorboard_log=tensorboard_log_dir, # Log to TensorBoard
           )

print("DQN model created.")
# Out:
# Using cuda device
# DQN model created.

# %%
total_episodes = 100 # Train for number passes through the data
total_timesteps = total_episodes * embeddings_train_aug.shape[0]  # Use augmented data

print(f"Total episodes: {total_episodes}")
print(f"Total timesteps: {total_timesteps}")
print(f"Training on {embeddings_train_aug.shape[0]} samples (including {len(synthetic_embeddings)} synthetic fraud samples)")
# Out:
# Total episodes: 100
# Total timesteps: 275500
# Training on 2755 samples (including 394 synthetic fraud samples)

# %% [markdown]
# ### Calculate Total Training Steps
#
# **Important**: We use `embeddings_train_aug` (augmented data) instead of the original `embeddings_train` because:
# - The training environment uses augmented data
# - This ensures timesteps calculation matches actual training data size
# - Includes both real and synthetic fraud samples

# %%
checkpoint_log_dir = "./dqn_fraud_checkpoints/" 
os.makedirs(checkpoint_log_dir, exist_ok=True)

checkpoint_callback = CheckpointCallback(save_freq=10000, save_path=checkpoint_log_dir, name_prefix='dqn_fraud_model')

# %%
# Train the model
model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)

print("Training finished.")
# Out:
# Logging to ./dqn_fraud_tb/DQN_1
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.76e+03  |
# |    ep_rew_mean      | -1.72e+03 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 1725      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 22040     |
# | train/              |           |
# |    learning_rate    | 9.2e-05   |
# |    loss             | 3.85      |
# |    n_updates        | 2629      |
# -----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.76e+03  |
# |    ep_rew_mean     | -1.72e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 1725      |
# |    time_elapsed    | 12        |
# |    total_timesteps | 22040     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 2.84e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1515     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 44080    |
# | train/              |          |
# |    learning_rate    | 8.4e-05  |
# |    loss             | 4.97     |
# |    n_updates        | 5384     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 2.84e+03 |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 1515     |
# |    time_elapsed    | 29       |
# |    total_timesteps | 44080    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 4.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1396     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 66120    |
# | train/              |          |
# |    learning_rate    | 7.6e-05  |
# |    loss             | 4.59     |
# |    n_updates        | 8139     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 4.38e+03 |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 1396     |
# |    time_elapsed    | 47       |
# |    total_timesteps | 66120    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 5.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1346     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 88160    |
# | train/              |          |
# |    learning_rate    | 6.8e-05  |
# |    loss             | 4.79     |
# |    n_updates        | 10894    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 5.19e+03 |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 1346     |
# |    time_elapsed    | 65       |
# |    total_timesteps | 88160    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 5.71e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1317     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 110200   |
# | train/              |          |
# |    learning_rate    | 6e-05    |
# |    loss             | 4.18     |
# |    n_updates        | 13649    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 5.71e+03 |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 1317     |
# |    time_elapsed    | 83       |
# |    total_timesteps | 110200   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.03e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1298     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 132240   |
# | train/              |          |
# |    learning_rate    | 5.2e-05  |
# |    loss             | 3.81     |
# |    n_updates        | 16404    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.03e+03 |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 1298     |
# |    time_elapsed    | 101      |
# |    total_timesteps | 132240   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.27e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1294     |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 154280   |
# | train/              |          |
# |    learning_rate    | 4.4e-05  |
# |    loss             | 3.82     |
# |    n_updates        | 19159    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.27e+03 |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 1294     |
# |    time_elapsed    | 119      |
# |    total_timesteps | 154280   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1287     |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 176320   |
# | train/              |          |
# |    learning_rate    | 3.6e-05  |
# |    loss             | 4.01     |
# |    n_updates        | 21914    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.46e+03 |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 1287     |
# |    time_elapsed    | 136      |
# |    total_timesteps | 176320   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1284     |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 198360   |
# | train/              |          |
# |    learning_rate    | 2.8e-05  |
# |    loss             | 3.24     |
# |    n_updates        | 24669    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.59e+03 |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 1284     |
# |    time_elapsed    | 154      |
# |    total_timesteps | 198360   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.7e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1282     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 220400   |
# | train/              |          |
# |    learning_rate    | 2e-05    |
# |    loss             | 3.4      |
# |    n_updates        | 27424    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.7e+03  |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1282     |
# |    time_elapsed    | 171      |
# |    total_timesteps | 220400   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.79e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1278     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 242440   |
# | train/              |          |
# |    learning_rate    | 1.2e-05  |
# |    loss             | 3.41     |
# |    n_updates        | 30179    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.79e+03 |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1278     |
# |    time_elapsed    | 189      |
# |    total_timesteps | 242440   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.76e+03 |
# |    ep_rew_mean      | 6.86e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1277     |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 264480   |
# | train/              |          |
# |    learning_rate    | 4e-06    |
# |    loss             | 3.53     |
# |    n_updates        | 32934    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.76e+03 |
# |    ep_rew_mean     | 6.86e+03 |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1277     |
# |    time_elapsed    | 207      |
# |    total_timesteps | 264480   |
# ---------------------------------
# Training finished.

# %% [markdown]
# ## Evaluate the Trained DQN Agent
#
# After training, we want to see how well the agent performs. We'll run it without exploration
#
#
#
# **Note: We create a separate environment instance using the test data and run the evaluation loop on it.**

# %%
eval_env = make_vec_env(FraudDetectionEnv,
                        env_kwargs={'embeddings': embeddings_test_pca,  # Use PCA-reduced test data
                                    'labels': labels_test,
                                    'reward_config': reward_config},
                        n_envs=1,
                        seed=43)
print("Evaluation Environment created with PCA-reduced test data (70D)")
# Out:
# Evaluation Environment created with PCA-reduced test data (70D)

# %%
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import time
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import io
from PIL import Image
import torch
import os


eval_log_dir = os.path.join(tensorboard_log_dir, "evaluation", f"eval_{time.strftime('%Y%m%d-%H%M%S')}")
writer = SummaryWriter(eval_log_dir)
print(f"TensorBoard logs will be saved to: {eval_log_dir}")

rewards_over_time = []

# Reset the environment for evaluation
obs = eval_env.reset()
done = False
total_reward = 0
predicted_labels = []
true_labels = []
instance_uids = []
episode_steps = 0
all_q_values = []
rewards_over_time = []  # Track rewards for plotting

# Use deterministic=True to turn off exploration (epsilon = 0)
while not done:
    # For Stable Baselines3 DQN, we can access q_values directly
    with torch.no_grad():
        # Convert observation to tensor
        obs_tensor = torch.FloatTensor(obs).to(model.device)
        # Get q_values using SB3's policy (this works for DQN)
        q_values = model.q_net(obs_tensor).detach().cpu().numpy()
    
    all_q_values.append(q_values)
    
    # Predict action
    action, _ = model.predict(obs, deterministic=True)
    action = action[0]
    
    # Step the environment
    obs, reward, done_flags, infos = eval_env.step([action])
    
    # Extract info for the single environment
    info = infos[0]
    done = done_flags[0]
    reward_value = reward[0]  # Reward is also a batch for VecEnv
    total_reward += reward_value
    rewards_over_time.append(reward_value)  # Store reward for plotting
    
    # Store results
    predicted_labels.append(action)
    true_labels.append(info['true_label'])
    instance_uids.append(info['instance_uid'])
    
    # Log immediate reward for this step
    writer.add_scalar('Evaluation/Step_Reward', reward_value, episode_steps)
    
    # Log Q-values for this step
    for i, q_val in enumerate(q_values[0]):
        writer.add_scalar(f'Evaluation/Q_Value_Action_{i}', q_val, episode_steps)
    
    # Log max Q-value
    writer.add_scalar('Evaluation/Max_Q_Value', np.max(q_values), episode_steps)
    
    # Log the chosen action
    writer.add_scalar('Evaluation/Action_Taken', action, episode_steps)
    
    episode_steps += 1
# Out:
# TensorBoard logs will be saved to: ./dqn_fraud_tb/evaluation/eval_20260311-125458

# %%
# Compute accuracy
accuracy = np.mean(np.array(predicted_labels) == np.array(true_labels))
writer.add_scalar('Evaluation/Accuracy', accuracy, 0)
writer.add_scalar('Evaluation/Total_Reward', total_reward, 0)
writer.add_scalar('Evaluation/Steps', episode_steps, 0)

# Create and log confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))  # Convert to CHW format
writer.add_image('Evaluation/Confusion_Matrix', img_tensor, 0)
plt.close()

# Log detailed classification metrics
class_names = [f"Class_{i}" for i in range(max(max(true_labels), max(predicted_labels)) + 1)]
report = classification_report(true_labels, predicted_labels, target_names=class_names)
writer.add_text('Evaluation/Classification_Report', '```\n' + report + '\n```', 0)

# Add class-wise metrics
for cls in range(len(class_names)):
    # Calculate class precision and recall
    true_positives = sum(1 for true, pred in zip(true_labels, predicted_labels) if true == cls and pred == cls)
    predicted_as_cls = sum(1 for pred in predicted_labels if pred == cls)
    actual_cls = sum(1 for true in true_labels if true == cls)
    
    precision = true_positives / predicted_as_cls if predicted_as_cls > 0 else 0
    recall = true_positives / actual_cls if actual_cls > 0 else 0
    
    writer.add_scalar(f'Evaluation/Class_{cls}_Precision', precision, 0)
    writer.add_scalar(f'Evaluation/Class_{cls}_Recall', recall, 0)

# Visualize average Q-values across the episode
all_q_values = np.array(all_q_values)
avg_q_values = np.mean(all_q_values, axis=0)[0]  # Average across steps
writer.add_scalar('Evaluation/Average_Max_Q_Value', np.max(avg_q_values), 0)

# Create bar plot of average Q-values
plt.figure(figsize=(10, 6))
plt.bar(range(len(avg_q_values)), avg_q_values)
plt.xlabel('Actions')
plt.ylabel('Average Q-Value')
plt.title('Average Q-Values Per Action')

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Average_Q_Values', img_tensor, 0)
plt.close()

# Create a plot of rewards over time
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(len(rewards_over_time)), rewards_over_time)
plt.xlabel('Step')
plt.ylabel('Step Reward')
plt.title('Rewards Per Step During Evaluation')
plt.grid(True)

plt.subplot(1, 2, 2)
cumulative_rewards = np.cumsum(rewards_over_time)
plt.plot(range(len(cumulative_rewards)), cumulative_rewards)
plt.xlabel('Step')
plt.ylabel('Cumulative Reward')
plt.title('Cumulative Reward During Evaluation')
plt.grid(True)

plt.tight_layout()

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Reward_Analysis', img_tensor, 0)
plt.close()

# Close the writer
writer.close()

print(f"Evaluation finished. Total reward: {total_reward}")
print(f"Accuracy: {accuracy:.4f}")
print(f"TensorBoard logs saved to {eval_log_dir}")
# Out:
# Evaluation finished. Total reward: 1017.0
# Accuracy: 0.9323
# TensorBoard logs saved to ./dqn_fraud_tb/evaluation/eval_20260311-125458

# %%
# Reset the environment for evaluation
# The environment will shuffle the data again for the evaluation run
obs = eval_env.reset()
done = False
total_reward = 0

predicted_labels = []
true_labels = []
instance_uids = []


# Use deterministic=True to turn off exploration (epsilon = 0)
while not done:

    action, _ = model.predict(obs, deterministic=True)

    action = action[0]

    # Step the environment
    obs, reward, done_flags, infos = eval_env.step([action])

    # Extract info for the single environment
    info = infos[0]
    done = done_flags[0]

    total_reward += reward[0] # Reward is also a batch for VecEnv

    # Store results
    predicted_labels.append(action)
    true_labels.append(info['true_label'])
    instance_uids.append(info['instance_uid'])

print(f"Evaluation finished. Total reward: {total_reward}")
# Out:
# Evaluation finished. Total reward: 1017.0

# %%
predicted_labels = np.array(predicted_labels)
true_labels = np.array(true_labels)


cm = confusion_matrix(true_labels, predicted_labels)

TN, FP, FN, TP = cm.ravel() if cm.size == 4 else (0,0,0,0)

print("\n--- Classification Metrics ---")
print("Confusion Matrix:")
print(f"TP: {TP}, FP: {FP}, FN: {FN}, TN: {TN}")


#plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# --- Classification Metrics ---
# Confusion Matrix:
# TP: 89, FP: 31, FN: 9, TN: 462

# %%
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, zero_division=0)
recall = recall_score(true_labels, predicted_labels, zero_division=0)
f1 = f1_score(true_labels, predicted_labels, zero_division=0)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (Class 1 - Fraud): {precision:.4f}")
print(f"Recall (Class 1 - Fraud): {recall:.4f}")
print(f"F1 Score (Class 1 - Fraud): {f1:.4f}")
# Out:
# Accuracy: 0.9323
# Precision (Class 1 - Fraud): 0.7417
# Recall (Class 1 - Fraud): 0.9082
# F1 Score (Class 1 - Fraud): 0.8165

# %% [markdown]
# Saving the Model

# %%
model_save_path = ".models/dqn_fraud_model2"
model.save(model_save_path)
print(f"\nModel saved to {model_save_path}")
# Out:
# Model saved to .models/dqn_fraud_model2
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:284: UserWarning: Path '.models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# ## THE ACTOR CRITIC MODEL

# %%
from stable_baselines3 import A2C

# %%
tensorboard_log_dir2 = "./a2c_fraud_tb/"
train_env.reset()
print("Training Environment reset.")
# Out:
# Training Environment reset.

# %%
checkpoint_log_dir2 = "./a2c_fraud_checkpoints/" 
os.makedirs(checkpoint_log_dir2, exist_ok=True)

checkpoint_callback2 = CheckpointCallback(save_freq=10000, save_path=checkpoint_log_dir2, name_prefix='A2C_fraud_model')

# %%
# Define the A2C model with MLP policy
ac_model = A2C(
    "MlpPolicy",
    train_env,
    learning_rate=1e-4,
    gamma=0.99,          # discount factor
    n_steps=5,           # how many steps to run for each update
    ent_coef=0.01,       # entropy bonus
    vf_coef=0.5,         # value function loss coefficient
    max_grad_norm=0.5,   # gradient clipping
    verbose=1,           # print training info
    device="auto",        # GPU if available
    tensorboard_log=tensorboard_log_dir2, # log to TensorBoard
    
)
print("A2C model created.")
# Out:
# Using cuda device
# A2C model created.
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Reuse the same total_timesteps you set for DQN
ac_model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback2)
print("A2C training finished.")
# Out:
# Logging to ./a2c_fraud_tb/A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 1636     |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.687   |
# |    explained_variance | -0.0175  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -7.43    |
# |    value_loss         | 327      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1614     |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | 0.0191   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -7.82    |
# |    value_loss         | 280      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1633     |
# |    iterations         | 300      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.644   |
# |    explained_variance | 0.0195   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 299      |
# |    policy_loss        | -2.76    |
# |    value_loss         | 123      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1681     |
# |    iterations         | 400      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.629   |
# |    explained_variance | -0.00891 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 399      |
# |    policy_loss        | -2.12    |
# |    value_loss         | 85.7     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1684     |
# |    iterations         | 500      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.56    |
# |    explained_variance | -0.0367  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.261    |
# |    value_loss         | 70.6     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76e+03  |
# |    ep_rew_mean        | -3.36e+03 |
# | time/                 |           |
# |    fps                | 1679      |
# |    iterations         | 600       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.509    |
# |    explained_variance | -0.0126   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.765    |
# |    value_loss         | 57        |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76e+03  |
# |    ep_rew_mean        | -3.36e+03 |
# | time/                 |           |
# |    fps                | 1704      |
# |    iterations         | 700       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -0.494    |
# |    explained_variance | 0.0922    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.714     |
# |    value_loss         | 56.7      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76e+03  |
# |    ep_rew_mean        | -3.36e+03 |
# | time/                 |           |
# |    fps                | 1700      |
# |    iterations         | 800       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.447    |
# |    explained_variance | 0.0283    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.727    |
# |    value_loss         | 169       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76e+03  |
# |    ep_rew_mean        | -3.36e+03 |
# | time/                 |           |
# |    fps                | 1706      |
# |    iterations         | 900       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.422    |
# |    explained_variance | 0.0479    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.787    |
# |    value_loss         | 200       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76e+03  |
# |    ep_rew_mean        | -3.36e+03 |
# | time/                 |           |
# |    fps                | 1700      |
# |    iterations         | 1000      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -0.408    |
# |    explained_variance | 0.0688    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 999       |
# |    policy_loss        | -1.89     |
# |    value_loss         | 98.2      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.76e+03  |
# |    ep_rew_mean        | -3.36e+03 |
# | time/                 |           |
# |    fps                | 1700      |
# |    iterations         | 1100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -0.358    |
# |    explained_variance | 0.0054    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1099      |
# |    policy_loss        | -2.96     |
# |    value_loss         | 141       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | -298     |
# | time/                 |          |
# |    fps                | 1718     |
# |    iterations         | 1200     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.332   |
# |    explained_variance | 0.155    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1199     |
# |    policy_loss        | 1.97     |
# |    value_loss         | 150      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | -298     |
# | time/                 |          |
# |    fps                | 1712     |
# |    iterations         | 1300     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.31    |
# |    explained_variance | 0.0251   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1299     |
# |    policy_loss        | -5.47    |
# |    value_loss         | 182      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | -298     |
# | time/                 |          |
# |    fps                | 1721     |
# |    iterations         | 1400     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.286   |
# |    explained_variance | 0.0807   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1399     |
# |    policy_loss        | 1.12     |
# |    value_loss         | 86       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | -298     |
# | time/                 |          |
# |    fps                | 1727     |
# |    iterations         | 1500     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.279   |
# |    explained_variance | 0.084    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1499     |
# |    policy_loss        | 2.11     |
# |    value_loss         | 136      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | -298     |
# | time/                 |          |
# |    fps                | 1731     |
# |    iterations         | 1600     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.278   |
# |    explained_variance | 0.0311   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1599     |
# |    policy_loss        | 3.03     |
# |    value_loss         | 164      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 1.6e+03  |
# | time/                 |          |
# |    fps                | 1723     |
# |    iterations         | 1700     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.241   |
# |    explained_variance | 0.0758   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1699     |
# |    policy_loss        | 2.22     |
# |    value_loss         | 91.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 1.6e+03  |
# | time/                 |          |
# |    fps                | 1718     |
# |    iterations         | 1800     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.22    |
# |    explained_variance | -0.0186  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.545    |
# |    value_loss         | 198      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 1.6e+03  |
# | time/                 |          |
# |    fps                | 1722     |
# |    iterations         | 1900     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.159   |
# |    explained_variance | 0.0227   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.656    |
# |    value_loss         | 177      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 1.6e+03  |
# | time/                 |          |
# |    fps                | 1724     |
# |    iterations         | 2000     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.191   |
# |    explained_variance | 0.065    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.612    |
# |    value_loss         | 130      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 1.6e+03  |
# | time/                 |          |
# |    fps                | 1722     |
# |    iterations         | 2100     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.191   |
# |    explained_variance | 0.00942  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2099     |
# |    policy_loss        | 2.41     |
# |    value_loss         | 178      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 1.6e+03  |
# | time/                 |          |
# |    fps                | 1728     |
# |    iterations         | 2200     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.139   |
# |    explained_variance | 0.221    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.682    |
# |    value_loss         | 190      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 2.95e+03 |
# | time/                 |          |
# |    fps                | 1729     |
# |    iterations         | 2300     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.148   |
# |    explained_variance | 0.16     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.0352  |
# |    value_loss         | 54.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 2.95e+03 |
# | time/                 |          |
# |    fps                | 1736     |
# |    iterations         | 2400     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.115   |
# |    explained_variance | -0.225   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.499    |
# |    value_loss         | 244      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 2.95e+03 |
# | time/                 |          |
# |    fps                | 1738     |
# |    iterations         | 2500     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.123   |
# |    explained_variance | 0.0896   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.85    |
# |    value_loss         | 258      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 2.95e+03 |
# | time/                 |          |
# |    fps                | 1741     |
# |    iterations         | 2600     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.129   |
# |    explained_variance | 0.179    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.0609   |
# |    value_loss         | 158      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 2.95e+03 |
# | time/                 |          |
# |    fps                | 1747     |
# |    iterations         | 2700     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.175   |
# |    explained_variance | -0.134   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2699     |
# |    policy_loss        | 1.08     |
# |    value_loss         | 124      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 3.87e+03 |
# | time/                 |          |
# |    fps                | 1746     |
# |    iterations         | 2800     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.082   |
# |    explained_variance | 0.0847   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.138   |
# |    value_loss         | 271      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 3.87e+03 |
# | time/                 |          |
# |    fps                | 1746     |
# |    iterations         | 2900     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.0996  |
# |    explained_variance | 0.0433   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2899     |
# |    policy_loss        | 1.57     |
# |    value_loss         | 69.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 3.87e+03 |
# | time/                 |          |
# |    fps                | 1747     |
# |    iterations         | 3000     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.0842  |
# |    explained_variance | 0.0875   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2999     |
# |    policy_loss        | 1.08     |
# |    value_loss         | 308      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 3.87e+03 |
# | time/                 |          |
# |    fps                | 1748     |
# |    iterations         | 3100     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.0697  |
# |    explained_variance | -0.389   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.142    |
# |    value_loss         | 99.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 3.87e+03 |
# | time/                 |          |
# |    fps                | 1750     |
# |    iterations         | 3200     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.13    |
# |    explained_variance | 0.145    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.474   |
# |    value_loss         | 208      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 3.87e+03 |
# | time/                 |          |
# |    fps                | 1747     |
# |    iterations         | 3300     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.0952  |
# |    explained_variance | 0.132    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.177   |
# |    value_loss         | 208      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 4.55e+03 |
# | time/                 |          |
# |    fps                | 1748     |
# |    iterations         | 3400     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.0835  |
# |    explained_variance | -0.0316  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0176  |
# |    value_loss         | 245      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 4.55e+03 |
# | time/                 |          |
# |    fps                | 1749     |
# |    iterations         | 3500     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.114   |
# |    explained_variance | -0.26    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3499     |
# |    policy_loss        | 2.34     |
# |    value_loss         | 320      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 4.55e+03 |
# | time/                 |          |
# |    fps                | 1750     |
# |    iterations         | 3600     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.0586  |
# |    explained_variance | -0.197   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.18    |
# |    value_loss         | 134      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 4.55e+03 |
# | time/                 |          |
# |    fps                | 1746     |
# |    iterations         | 3700     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.0564  |
# |    explained_variance | 0.0385   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.282    |
# |    value_loss         | 261      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 4.55e+03 |
# | time/                 |          |
# |    fps                | 1745     |
# |    iterations         | 3800     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.0658  |
# |    explained_variance | -0.00145 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0647   |
# |    value_loss         | 208      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.08e+03 |
# | time/                 |          |
# |    fps                | 1749     |
# |    iterations         | 3900     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 156000   |
# | train/                |          |
# |    entropy_loss       | -0.0307  |
# |    explained_variance | 0.0148   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0657   |
# |    value_loss         | 172      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.08e+03 |
# | time/                 |          |
# |    fps                | 1748     |
# |    iterations         | 4000     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -0.0833  |
# |    explained_variance | -0.178   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.995    |
# |    value_loss         | 132      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.08e+03 |
# | time/                 |          |
# |    fps                | 1751     |
# |    iterations         | 4100     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 164000   |
# | train/                |          |
# |    entropy_loss       | -0.0775  |
# |    explained_variance | -0.105   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.956    |
# |    value_loss         | 355      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.08e+03 |
# | time/                 |          |
# |    fps                | 1753     |
# |    iterations         | 4200     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -0.0547  |
# |    explained_variance | 0.11     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.107   |
# |    value_loss         | 129      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.08e+03 |
# | time/                 |          |
# |    fps                | 1754     |
# |    iterations         | 4300     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 172000   |
# | train/                |          |
# |    entropy_loss       | -0.0756  |
# |    explained_variance | -0.503   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.637    |
# |    value_loss         | 249      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.08e+03 |
# | time/                 |          |
# |    fps                | 1756     |
# |    iterations         | 4400     |
# |    time_elapsed       | 100      |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -0.0214  |
# |    explained_variance | -0.0898  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.286    |
# |    value_loss         | 219      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.48e+03 |
# | time/                 |          |
# |    fps                | 1755     |
# |    iterations         | 4500     |
# |    time_elapsed       | 102      |
# |    total_timesteps    | 180000   |
# | train/                |          |
# |    entropy_loss       | -0.0441  |
# |    explained_variance | -0.0455  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.075    |
# |    value_loss         | 152      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.48e+03 |
# | time/                 |          |
# |    fps                | 1756     |
# |    iterations         | 4600     |
# |    time_elapsed       | 104      |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -0.0197  |
# |    explained_variance | 0.0837   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0103   |
# |    value_loss         | 183      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.48e+03 |
# | time/                 |          |
# |    fps                | 1756     |
# |    iterations         | 4700     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 188000   |
# | train/                |          |
# |    entropy_loss       | -0.104   |
# |    explained_variance | 0.0705   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.445    |
# |    value_loss         | 182      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.48e+03 |
# | time/                 |          |
# |    fps                | 1756     |
# |    iterations         | 4800     |
# |    time_elapsed       | 109      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.0666  |
# |    explained_variance | -0.0239  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.081   |
# |    value_loss         | 101      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.48e+03 |
# | time/                 |          |
# |    fps                | 1760     |
# |    iterations         | 4900     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 196000   |
# | train/                |          |
# |    entropy_loss       | -0.0558  |
# |    explained_variance | -0.0326  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.411    |
# |    value_loss         | 112      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.81e+03 |
# | time/                 |          |
# |    fps                | 1760     |
# |    iterations         | 5000     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -0.0307  |
# |    explained_variance | 0.0992   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0895   |
# |    value_loss         | 182      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.81e+03 |
# | time/                 |          |
# |    fps                | 1762     |
# |    iterations         | 5100     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 204000   |
# | train/                |          |
# |    entropy_loss       | -0.0181  |
# |    explained_variance | -0.0251  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0145   |
# |    value_loss         | 73.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.81e+03 |
# | time/                 |          |
# |    fps                | 1758     |
# |    iterations         | 5200     |
# |    time_elapsed       | 118      |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -0.0392  |
# |    explained_variance | 0.0451   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.386   |
# |    value_loss         | 209      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.81e+03 |
# | time/                 |          |
# |    fps                | 1757     |
# |    iterations         | 5300     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 212000   |
# | train/                |          |
# |    entropy_loss       | -0.0392  |
# |    explained_variance | 0.0795   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5299     |
# |    policy_loss        | -1.16    |
# |    value_loss         | 109      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.81e+03 |
# | time/                 |          |
# |    fps                | 1760     |
# |    iterations         | 5400     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -0.0447  |
# |    explained_variance | -0.059   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.302   |
# |    value_loss         | 78.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 5.81e+03 |
# | time/                 |          |
# |    fps                | 1759     |
# |    iterations         | 5500     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 220000   |
# | train/                |          |
# |    entropy_loss       | -0.0415  |
# |    explained_variance | 0.00823  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.425    |
# |    value_loss         | 122      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.08e+03 |
# | time/                 |          |
# |    fps                | 1760     |
# |    iterations         | 5600     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -0.0266  |
# |    explained_variance | 0.00878  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0249   |
# |    value_loss         | 145      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.08e+03 |
# | time/                 |          |
# |    fps                | 1759     |
# |    iterations         | 5700     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 228000   |
# | train/                |          |
# |    entropy_loss       | -0.0564  |
# |    explained_variance | 0.0313   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.274    |
# |    value_loss         | 135      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.08e+03 |
# | time/                 |          |
# |    fps                | 1759     |
# |    iterations         | 5800     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 232000   |
# | train/                |          |
# |    entropy_loss       | -0.0777  |
# |    explained_variance | -0.00275 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.44     |
# |    value_loss         | 144      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.08e+03 |
# | time/                 |          |
# |    fps                | 1761     |
# |    iterations         | 5900     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 236000   |
# | train/                |          |
# |    entropy_loss       | -0.0341  |
# |    explained_variance | 0.0405   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.405   |
# |    value_loss         | 126      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.08e+03 |
# | time/                 |          |
# |    fps                | 1761     |
# |    iterations         | 6000     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -0.0405  |
# |    explained_variance | 0.0103   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0964   |
# |    value_loss         | 96       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.32e+03 |
# | time/                 |          |
# |    fps                | 1763     |
# |    iterations         | 6100     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 244000   |
# | train/                |          |
# |    entropy_loss       | -0.034   |
# |    explained_variance | 0.00252  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0564   |
# |    value_loss         | 222      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.32e+03 |
# | time/                 |          |
# |    fps                | 1764     |
# |    iterations         | 6200     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -0.0295  |
# |    explained_variance | 0.0194   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.363   |
# |    value_loss         | 178      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.32e+03 |
# | time/                 |          |
# |    fps                | 1768     |
# |    iterations         | 6300     |
# |    time_elapsed       | 142      |
# |    total_timesteps    | 252000   |
# | train/                |          |
# |    entropy_loss       | -0.0126  |
# |    explained_variance | 0.00876  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.0375   |
# |    value_loss         | 198      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.32e+03 |
# | time/                 |          |
# |    fps                | 1773     |
# |    iterations         | 6400     |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -0.0414  |
# |    explained_variance | 0.00805  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0623  |
# |    value_loss         | 167      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.32e+03 |
# | time/                 |          |
# |    fps                | 1773     |
# |    iterations         | 6500     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 260000   |
# | train/                |          |
# |    entropy_loss       | -0.0397  |
# |    explained_variance | 0.00287  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.159   |
# |    value_loss         | 83.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.32e+03 |
# | time/                 |          |
# |    fps                | 1776     |
# |    iterations         | 6600     |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -0.0208  |
# |    explained_variance | 0.0139   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.204    |
# |    value_loss         | 97.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.52e+03 |
# | time/                 |          |
# |    fps                | 1782     |
# |    iterations         | 6700     |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 268000   |
# | train/                |          |
# |    entropy_loss       | -0.0229  |
# |    explained_variance | 0.1      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.025    |
# |    value_loss         | 105      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.76e+03 |
# |    ep_rew_mean        | 6.52e+03 |
# | time/                 |          |
# |    fps                | 1787     |
# |    iterations         | 6800     |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -0.0501  |
# |    explained_variance | 0.00807  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.817    |
# |    value_loss         | 178      |
# ------------------------------------
# A2C training finished.

# %%
# Reset the eval environment
obs = eval_env.reset()
done = False
predicted_labels_ac = []
true_labels_ac = []
instance_uids_ac = []
total_reward_ac = 0

# Turn off exploration for evaluation
while not done:
    action, _ = ac_model.predict(obs, deterministic=True)
    action = action[0]
    obs, reward, done_flags, infos = eval_env.step([action])
    info = infos[0]
    done = done_flags[0]
    total_reward_ac += reward[0]
    predicted_labels_ac.append(action)
    true_labels_ac.append(info['true_label'])
    instance_uids_ac.append(info['instance_uid'])

print(f"A2C Evaluation finished. Total reward: {total_reward_ac}")
# Out:
# A2C Evaluation finished. Total reward: 951.0

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare arrays
predicted_labels_ac = np.array(predicted_labels_ac)
true_labels_ac = np.array(true_labels_ac)

# Compute matrix
cm_ac = confusion_matrix(true_labels_ac, predicted_labels_ac)
TN, FP, FN, TP = cm_ac.ravel() if cm_ac.size == 4 else (0,0,0,0)

print("\n--- A2C Classification Metrics ---")
print(f"TP: {TP}, FP: {FP}, FN: {FN}, TN: {TN}")

# Plot
sns.heatmap(cm_ac, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('A2C Confusion Matrix')
plt.show()
# Out:
# --- A2C Classification Metrics ---
# TP: 85, FP: 22, FN: 13, TN: 471

# %%
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import time
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import io
from PIL import Image
import torch
import os

# Create TensorBoard writer - using the same log dir as during training
# but in a separate "evaluation" subfolder
eval_log_dir = os.path.join(tensorboard_log_dir2, "evaluation", f"a2c_eval_{time.strftime('%Y%m%d-%H%M%S')}")
writer = SummaryWriter(eval_log_dir)
print(f"TensorBoard logs will be saved to: {eval_log_dir}")

# Lists to store data for visualization
rewards_over_time = []
values_over_time = []
action_probs_over_time = []
entropies = []

# Reset the environment for evaluation
obs = eval_env.reset()
done = False
total_reward = 0
predicted_labels = []
true_labels = []
instance_uids = []
episode_steps = 0

# Use deterministic=True to turn off exploration
while not done:
    # For A2C, we can get action probabilities and state values
    with torch.no_grad():
        # Convert observation to tensor
        obs_tensor = torch.FloatTensor(obs).to(ac_model.policy.device)
        
        # Access the policy network and value network directly
        # This is the correct way to access the policy in SB3 A2C
        features = ac_model.policy.extract_features(obs_tensor)
        
        # Get action distribution
        latent_pi, latent_vf = ac_model.policy.mlp_extractor(features)
        action_logits = ac_model.policy.action_net(latent_pi)
        
        # Calculate action probabilities (softmax of logits for discrete actions)
        action_probs = torch.softmax(action_logits, dim=1)
        
        # Get value function prediction
        values = ac_model.policy.value_net(latent_vf)
        
        # Calculate entropy (measure of exploration)
        # For categorical/discrete actions, entropy is -sum(p*log(p))
        log_probs = torch.log_softmax(action_logits, dim=1)
        entropy = -torch.sum(action_probs * log_probs, dim=1).mean().item()
    
    # Store data for visualization
    action_probs_over_time.append(action_probs.cpu().numpy()[0])
    values_over_time.append(values.cpu().numpy()[0][0])
    entropies.append(entropy)
    
    # Predict action (deterministic = use most probable action)
    action, _ = ac_model.predict(obs, deterministic=True)
    action = action[0]
    
    # Log action probabilities
    for i, prob in enumerate(action_probs.cpu().numpy()[0]):
        writer.add_scalar(f'Evaluation/Action_Prob_{i}', prob, episode_steps)
    
    # Log value function and entropy
    writer.add_scalar('Evaluation/Value_Function', values.cpu().numpy()[0][0], episode_steps)
    writer.add_scalar('Evaluation/Policy_Entropy', entropy, episode_steps)
    
    # Step the environment
    obs, reward, done_flags, infos = eval_env.step([action])
    
    # Extract info for the single environment
    info = infos[0]
    done = done_flags[0]
    reward_value = reward[0]  # Reward is also a batch for VecEnv
    total_reward += reward_value
    rewards_over_time.append(reward_value)
    
    # Store results
    predicted_labels.append(action)
    true_labels.append(info['true_label'])
    instance_uids.append(info['instance_uid'])
    
    # Log immediate reward for this step
    writer.add_scalar('Evaluation/Step_Reward', reward_value, episode_steps)
    
    # Log the chosen action
    writer.add_scalar('Evaluation/Action_Taken', action, episode_steps)
    
    episode_steps += 1

# Compute accuracy
accuracy = np.mean(np.array(predicted_labels) == np.array(true_labels))
writer.add_scalar('Evaluation/Accuracy', accuracy, 0)
writer.add_scalar('Evaluation/Total_Reward', total_reward, 0)
writer.add_scalar('Evaluation/Steps', episode_steps, 0)

# Create and log confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))  # Convert to CHW format
writer.add_image('Evaluation/Confusion_Matrix', img_tensor, 0)
plt.close()

# Log detailed classification metrics
class_names = [f"Class_{i}" for i in range(max(max(true_labels), max(predicted_labels)) + 1)]
report = classification_report(true_labels, predicted_labels, target_names=class_names)
writer.add_text('Evaluation/Classification_Report', '```\n' + report + '\n```', 0)

# Add class-wise metrics
for cls in range(len(class_names)):
    # Calculate class precision and recall
    true_positives = sum(1 for true, pred in zip(true_labels, predicted_labels) if true == cls and pred == cls)
    predicted_as_cls = sum(1 for pred in predicted_labels if pred == cls)
    actual_cls = sum(1 for true in true_labels if true == cls)
    
    precision = true_positives / predicted_as_cls if predicted_as_cls > 0 else 0
    recall = true_positives / actual_cls if actual_cls > 0 else 0
    
    writer.add_scalar(f'Evaluation/Class_{cls}_Precision', precision, 0)
    writer.add_scalar(f'Evaluation/Class_{cls}_Recall', recall, 0)

# Create a plot of rewards and value function over time
plt.figure(figsize=(12, 8))

# Plot rewards
plt.subplot(2, 2, 1)
plt.plot(range(len(rewards_over_time)), rewards_over_time)
plt.xlabel('Step')
plt.ylabel('Step Reward')
plt.title('Rewards Per Step')
plt.grid(True)

# Plot cumulative rewards
plt.subplot(2, 2, 2)
cumulative_rewards = np.cumsum(rewards_over_time)
plt.plot(range(len(cumulative_rewards)), cumulative_rewards)
plt.xlabel('Step')
plt.ylabel('Cumulative Reward')
plt.title('Cumulative Reward')
plt.grid(True)

# Plot value function estimates
plt.subplot(2, 2, 3)
plt.plot(range(len(values_over_time)), values_over_time)
plt.xlabel('Step')
plt.ylabel('Value Estimate')
plt.title('Value Function Estimates')
plt.grid(True)

# Plot advantage (reward - value) to see if value function is accurate
plt.subplot(2, 2, 4)
advantages = [r - v for r, v in zip(rewards_over_time, values_over_time)]
plt.plot(range(len(advantages)), advantages)
plt.xlabel('Step')
plt.ylabel('Advantage (Reward - Value)')
plt.title('Advantage Estimates')
plt.grid(True)

plt.tight_layout()

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Reward_Value_Analysis', img_tensor, 0)
plt.close()

# Visualize action probabilities over time (policy evolution)
plt.figure(figsize=(12, 6))

# Plot action probabilities
plt.subplot(1, 2, 1)
action_probs_array = np.array(action_probs_over_time)
for i in range(action_probs_array.shape[1]):
    plt.plot(range(len(action_probs_over_time)), action_probs_array[:, i], label=f'Action {i}')
plt.xlabel('Step')
plt.ylabel('Action Probability')
plt.title('Action Probabilities Over Time')
plt.legend()
plt.grid(True)

# Plot entropy
plt.subplot(1, 2, 2)
plt.plot(range(len(entropies)), entropies)
plt.xlabel('Step')
plt.ylabel('Entropy')
plt.title('Policy Entropy Over Time')
plt.grid(True)

plt.tight_layout()

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Policy_Analysis', img_tensor, 0)
plt.close()

# Close the writer
writer.close()

print(f"Evaluation finished. Total reward: {total_reward}")
print(f"Accuracy: {accuracy:.4f}")
print(f"TensorBoard logs saved to {eval_log_dir}")
print("To view TensorBoard visualization, run:")
print(f"tensorboard --logdir={tensorboard_log_dir}")  # Point to the parent log dir to see both training and evaluation
# Out:
# TensorBoard logs will be saved to: ./a2c_fraud_tb/evaluation/a2c_eval_20260311-125735
# Evaluation finished. Total reward: 951.0
# Accuracy: 0.9408
# TensorBoard logs saved to ./a2c_fraud_tb/evaluation/a2c_eval_20260311-125735
# To view TensorBoard visualization, run:
# tensorboard --logdir=./dqn_fraud_tb/

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_ac  = accuracy_score(true_labels_ac, predicted_labels_ac)
precision_ac = precision_score(true_labels_ac, predicted_labels_ac, zero_division=0)
recall_ac    = recall_score(true_labels_ac, predicted_labels_ac, zero_division=0)
f1_ac        = f1_score(true_labels_ac, predicted_labels_ac, zero_division=0)

print(f"A2C Accuracy: {accuracy_ac:.4f}")
print(f"A2C Precision (Class 1 - Fraud): {precision_ac:.4f}")
print(f"A2C Recall    (Class 1 - Fraud): {recall_ac:.4f}")
print(f"A2C F1 Score  (Class 1 - Fraud): {f1_ac:.4f}")
# Out:
# A2C Accuracy: 0.9408
# A2C Precision (Class 1 - Fraud): 0.7944
# A2C Recall    (Class 1 - Fraud): 0.8673
# A2C F1 Score  (Class 1 - Fraud): 0.8293

# %%
# 1. Choose a save path (no need to add “.zip”—SB3 will append it for you)
save_path = ".models/a2c_fraud_model2"

# 2. Save your A2C model
ac_model.save(save_path)

# 3. Confirm it on screen
print(f"A2C model saved to {save_path}.zip")
# Out:
# A2C model saved to .models/a2c_fraud_model2.zip

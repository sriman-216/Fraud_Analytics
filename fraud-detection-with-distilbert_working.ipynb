# %% [markdown]
# # Fraud Detection with DistilBERT

# %% [markdown]
# # 1. Setup
#
# **Install Dependencies**
#
# **Purpose:** Installs required libraries, ensuring compatibility with the Kaggle environment. We use specific versions for reproducibility and include onnx for model optimization.

# %%
# # Install required libraries
# !pip install transformers datasets torch pandas numpy scikit-learn
# !pip install onnx onnxruntime  # For model optimization
# # Update transformers to the latest version
# !pip install --upgrade transformers

# %%
# !pip install transformers[torch]
# !pip install -U accelerate
import sys
print(sys.executable)
# !{sys.executable} -m pip list | grep accelerate

import accelerate
print(accelerate.__file__)
print(accelerate.__version__)

import sys
# !{sys.executable} -m pip uninstall -y transformers accelerate
# !{sys.executable} -m pip install "transformers==4.51.3" "accelerate>=1.1.0" "datasets" "evaluate"
import transformers; print(transformers.__version__)
# !pip install seaborn matplotlib
# !pip install onnx onnxruntime
# Out:
# Requirement already satisfied: transformers[torch] in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (4.51.3)
# Requirement already satisfied: filelock in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (3.24.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (2026.1.15)
# Requirement already satisfied: requests in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (2.10.0)
# Requirement already satisfied: accelerate>=0.26.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers[torch]) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers[torch]) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: psutil in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate>=0.26.0->transformers[torch]) (7.2.2)
# Requirement already satisfied: sympy>=1.13.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (3.4.2)
# Requirement already satisfied: jinja2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0->transformers[torch]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=2.0->transformers[torch]) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from jinja2->torch>=2.0->transformers[torch]) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->transformers[torch]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->transformers[torch]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->transformers[torch]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->transformers[torch]) (2026.1.4)
# Requirement already satisfied: accelerate in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: numpy>=1.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (25.0)
# Requirement already satisfied: psutil in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: pyyaml in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (2.10.0)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (0.36.2)
# Requirement already satisfied: safetensors>=0.4.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (1.4.0)
# Requirement already satisfied: requests in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface_hub>=0.21.0->accelerate) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->huggingface_hub>=0.21.0->accelerate) (2026.1.4)
# /data1/rachit/.conda/envs/cond/bin/python
# accelerate               1.13.0
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/accelerate/__init__.py
# 1.13.0
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Successfully uninstalled transformers-4.51.3
# Found existing installation: accelerate 1.13.0
# Uninstalling accelerate-1.13.0:
#   Successfully uninstalled accelerate-1.13.0
# Collecting transformers==4.51.3
#   Using cached transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Collecting accelerate>=1.1.0
#   Using cached accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: datasets in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (4.7.0)
# Requirement already satisfied: evaluate in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (0.4.6)
# Requirement already satisfied: filelock in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (3.24.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (2026.1.15)
# Requirement already satisfied: requests in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (2.32.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from transformers==4.51.3) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.51.3) (4.15.0)
# Requirement already satisfied: psutil in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate>=1.1.0) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from accelerate>=1.1.0) (2.10.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: httpx<1.0.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->transformers==4.51.3) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from requests->transformers==4.51.3) (2.6.3)
# Requirement already satisfied: sympy>=1.13.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from torch>=2.0.0->accelerate>=1.1.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=2.0.0->accelerate>=1.1.0) (1.3.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.1.0) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate>=1.1.0) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached transformers-4.51.3-py3-none-any.whl (10.4 MB)
# Using cached accelerate-1.13.0-py3-none-any.whl (383 kB)
# Installing collected packages: transformers, accelerate
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [accelerate]s]
# Successfully installed accelerate-1.13.0 transformers-4.51.3
# 4.40.2
# Requirement already satisfied: seaborn in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: onnx in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (1.20.1)
# Requirement already satisfied: onnxruntime in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (1.23.2)
# Requirement already satisfied: numpy>=1.23.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnx) (2.2.6)
# Requirement already satisfied: protobuf>=4.25.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnx) (6.33.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnx) (0.5.4)
# Requirement already satisfied: coloredlogs in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: packaging in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: sympy in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import torch
print("GPU count:", torch.cuda.device_count())
print("Using:", torch.cuda.get_device_name(0))
# Out:
# GPU count: 1
# Using: NVIDIA A40

# %% [markdown]
# **Notes:**
#
#
# * transformers==4.51.3 ensures stable DistilBERT functionality.
# * onnx and onnxruntime prepare the model for efficient deployment.
# * Run this in a Kaggle notebook with GPU enabled for faster training.

# %% [markdown]
# # 2. Data Preparation
#
# **Load and Preprocess Data**
#
# **Purpose:** Loads the dataset, creates synthetic text descriptions from Amount and Time, balances the dataset (1:5 fraud-to-non-fraud ratio), and tokenizes it for DistilBERT.

# %%
# from kagglehub import KaggleDatasetAdapter

# # Set the path to the file you'd like to load
# file_path = ""

# # Load the latest version
# df = kagglehub.load_dataset(
#   KaggleDatasetAdapter.PANDAS,
#   "mlg-ulb/creditcardfraud",
#   file_path,
#   # Provide any additional arguments like 
#   # sql_query or pandas_kwargs. See the 
#   # documenation for more information:
#   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
# )

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset

# Load the dataset
data_orig = pd.read_csv('./creditcard.csv')

# Verify the data
print("Dataset shape:", data_orig.shape)
print("First few rows of the dataset:")
# (data_orig.head())
# Out:
# Dataset shape: (284807, 31)
# First few rows of the dataset:

# %%
# Create synthetic text descriptions
data = data_orig
data['text'] = data_orig.apply(lambda x: f"Transaction of ${x['Amount']:.2f} at time {x['Time']:.0f} seconds", axis=1)
# data

# %%
# Select relevant columns
data = data[['text', 'Class']].rename(columns={'Class': 'label'})

# Handle class imbalance (optional: undersample non-fraudulent transactions)
fraud = data[data['label'] == 1]
non_fraud = data[data['label'] == 0].sample(n=len(fraud) * 5, random_state=42)  # 1:5 ratio
balanced_data = pd.concat([fraud, non_fraud]).sample(frac=1, random_state=42)

# Split into train and test sets
train_data, test_data = train_test_split(balanced_data, test_size=0.2, random_state=42)

# Convert to Hugging Face Dataset
train_dataset = Dataset.from_pandas(train_data)
test_dataset = Dataset.from_pandas(test_data)
print(train_dataset.shape)
print(test_dataset.shape)
# Out:
# (2361, 3)
# (591, 3)

# %%
train_dataset.features
# Out:
# {'text': Value('string'),
#  'label': Value('int64'),
#  '__index_level_0__': Value('int64')}

# %% [markdown]
# Tokenize the dataset

# %%
from transformers import DistilBertTokenizer

tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

def tokenize_function(rows):
    return tokenizer(rows['text'], padding='max_length', truncation=True, max_length=128)

# Tokenize datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set format for PyTorch
train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
# train_dataset.shape
# Out:
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map: 100%|██████████| 2361/2361 [00:00<00:00, 5772.71 examples/s]
# Map: 100%|██████████| 591/591 [00:00<00:00, 5109.15 examples/s]

# %% [markdown]
# **Notes:**
#
# * Dataset: Contains 284,807 transactions, with Time, Amount, V1–V28 (PCA features), and Class (0: legitimate, 1: fraud).
# * Balancing: Undersampling creates ~2,952 samples (492 fraud, 2,460 non-fraud), improving model focus on fraud.
# * Tokenization: Uses max_length=128 for efficiency with simple text descriptions.
# Output: Confirms dataset shape and sample rows (see your output for details).

# %% [markdown]
# # 3. Initial Model Training
#
# **Train DistilBERT**
#
# **Purpose:** Fine-tunes distilbert-base-uncased for binary classification, establishing a baseline performance.

# %%
import torch
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer, TrainingArguments, Trainer


# Load model (use distilbert-base-uncased due to local model loading failure)
model = DistilBertForSequenceClassification.from_pretrained(
    'distilbert-base-uncased',
    num_labels=2  # Binary classification (fraud vs. legitimate)
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Define training arguments
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=1,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy='epoch',
    load_best_model_at_end=True,
    report_to='none',  
    ddp_find_unused_parameters=False
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=lambda pred: {
        'accuracy': (pred.predictions.argmax(-1) == pred.label_ids).mean()
    }
)

# %%
trainer.train()        # must run first
eval_results = trainer.evaluate(eval_dataset=test_dataset)

print("Evaluation results:", eval_results)
# Out:
#     <div>
#
#       <progress value='296' max='296' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [296/296 00:15, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.556500</td>
#       <td>0.445845</td>
#       <td>0.822335</td>
#     </tr>
#   </tbody>
# </table><p>
# Evaluation results: {'eval_loss': 0.445844829082489, 'eval_accuracy': 0.8223350253807107, 'eval_runtime': 0.6371, 'eval_samples_per_second': 927.578, 'eval_steps_per_second': 116.143, 'epoch': 1.0}

# %% [markdown]
# **Notes:**
#
#
# * **Model:** distilbert-base-uncased is lightweight and effective for text classification.
# * **Hyperparameters:** 3 epochs, batch size 8, and 500 warmup steps balance training speed and stability.
# * **Output:** Achieves 81.22% accuracy with 0.17 fraud recall, indicating bias toward the majority class (see your output).

# %% [markdown]
# # 4. Initial Model Evaluation
#
# **Evaluate Initial Performance**
#
# **Purpose**: Assesses the initial model’s performance that highlights the need for improvement in fraud detection.

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Get predictions
predictions = trainer.predict(test_dataset)
preds = np.argmax(predictions.predictions, axis=-1)
labels = predictions.label_ids

# Print classification report
print("Classification Report:")
print(classification_report(labels, preds, target_names=['Legitimate', 'Fraud']))

# Print confusion matrix
print("Confusion Matrix:")
print(confusion_matrix(labels, preds))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   Legitimate       0.82      1.00      0.90       482
#        Fraud       0.83      0.05      0.09       109
#
#     accuracy                           0.82       591
#    macro avg       0.83      0.52      0.49       591
# weighted avg       0.82      0.82      0.75       591
#
# Confusion Matrix:
# [[481   1]
#  [104   5]]

# %% [markdown]
# # 5. Threshold Adjustment (Exploratory)
#
# **Adjust Classification Threshold**
#
# **Purpose**: Explores threshold adjustment to increase fraud recall, though it significantly reduces accuracy.

# %% [markdown]
# # 7. Threshold Adjustment for Weighted Loss
#
# **Adjust Threshold for Weighted Model**
#
# **Purpose**: Tests threshold adjustment on the weighted loss model to maximize fraud recall.

# %%
from sklearn.metrics import classification_report, precision_recall_curve
import numpy as np
import torch

# Get prediction probabilities
predictions = trainer.predict(test_dataset)
probs = torch.softmax(torch.tensor(predictions.predictions), dim=-1)[:, 1].numpy()
labels = predictions.label_ids

# Compute precision-recall curve
precision, recall, thresholds = precision_recall_curve(labels, probs)

# Find threshold for ~80% recall
optimal_idx = np.argmax(recall >= 0.8)
optimal_threshold = thresholds[optimal_idx]
print(f"Optimal threshold for ~80% fraud recall: {optimal_threshold:.3f}")

# Apply threshold
preds_adjusted = (probs >= optimal_threshold).astype(int)

# Print adjusted metrics
print("Adjusted Classification Report:")
print(classification_report(labels, preds_adjusted, target_names=['Legitimate', 'Fraud']))
print("Adjusted Confusion Matrix:")
print(confusion_matrix(labels, preds_adjusted))
# Out:
#     <div>
#
#       <progress value='6' max='74' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 6/74 00:00 < 00:00, 105.44 it/s]
#     </div>
# Optimal threshold for ~80% fraud recall: 0.045
# Adjusted Classification Report:
#               precision    recall  f1-score   support
#
#   Legitimate       0.00      0.00      0.00       482
#        Fraud       0.18      1.00      0.31       109
#
#     accuracy                           0.18       591
#    macro avg       0.09      0.50      0.16       591
# weighted avg       0.03      0.18      0.06       591
#
# Adjusted Confusion Matrix:
# [[  0 482]
#  [  0 109]]
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# # 8. Feature Engineering
#
# **Prepare Feature-Engineered Dataset**
#
# **Purpose**: Enhances the dataset by including V1–V8 features in the text descriptions, increasing max_length to 256 for richer input.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset
from transformers import DistilBertTokenizer

# Load dataset
data = pd.read_csv('./creditcard.csv')

# Create enhanced text
data['text'] = data.apply(
    lambda x: f"Transaction of ${x['Amount']:.2f} at time {x['Time']:.0f} seconds, "
              f"V1={x['V1']:.2f}, V2={x['V2']:.2f}, V3={x['V3']:.2f}, V4={x['V4']:.2f}, "
              f"V5={x['V5']:.2f}, V6={x['V6']:.2f}, V7={x['V7']:.2f}, V8={x['V8']:.2f}",
    axis=1
)
data = data[['text', 'Class']].rename(columns={'Class': 'label'})

# Balance dataset
fraud = data[data['label'] == 1]
non_fraud = data[data['label'] == 0].sample(n=len(fraud) * 5, random_state=42)
balanced_data = pd.concat([fraud, non_fraud]).sample(frac=1, random_state=42)

# Split
train_data, test_data = train_test_split(balanced_data, test_size=0.2, random_state=42)
train_dataset = Dataset.from_pandas(train_data)
test_dataset = Dataset.from_pandas(test_data)

# Tokenize
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=256)

train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
train_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format('torch', columns=['input_ids', 'attention_mask', 'label'])

# Retrain with weighted loss (use weighted_loss_fixed_dataparallel.py)
# Out:
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map: 100%|██████████| 2361/2361 [00:00<00:00, 2465.96 examples/s]
# Map: 100%|██████████| 591/591 [00:00<00:00, 2285.50 examples/s]

# %% [markdown]
# **Notes**:
#
# * **Features**: Adds V1–V8 (PCA components) to capture more transaction patterns.
# * **Tokenization**: Increases max_length to 256 to accommodate longer text.
# * **Output**: Prepares the dataset for retraining (no evaluation yet).

# %% [markdown]
# # 10. Retrain with Weighted Loss on Feature-Engineered Dataset
#
# **Retrain for Optimal Performance**
#
# **Purpose**: Retrains the model with weighted loss on the feature-engineered dataset, achieving the final 93% accuracy.

# %%
from transformers import Trainer, DistilBertForSequenceClassification, TrainingArguments
import torch
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Load best checkpoint (epoch 1, 81.56% accuracy)
model = DistilBertForSequenceClassification.from_pretrained('./results/checkpoint-296')

class WeightedTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, num_items_in_batch=None):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits
        # Get device from model parameters to handle DataParallel
        device = next(model.parameters()).device
        # Class weights: 1.0 for legitimate, 10.0 for fraud
        class_weights = torch.tensor([1.0, 10.0]).to(device)
        loss_fct = torch.nn.CrossEntropyLoss(weight=class_weights)
        loss = loss_fct(logits, labels)
        return (loss, outputs) if return_outputs else loss

# Define training arguments
training_args = TrainingArguments(
    output_dir='./results_weighted',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs_weighted',
    logging_steps=10,
    evaluation_strategy='epoch',   # corrected
    save_strategy='epoch',
    load_best_model_at_end=True,
    report_to='none'
)

# Initialize WeightedTrainer
trainer = WeightedTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=lambda pred: {'accuracy': (pred.predictions.argmax(-1) == pred.label_ids).mean()}
)

# Train
trainer.train()

# Evaluate
eval_results = trainer.evaluate()
print("Weighted Loss Evaluation Results:", eval_results)

# Detailed evaluation
predictions = trainer.predict(test_dataset)
preds = np.argmax(predictions.predictions, axis=-1)
labels = predictions.label_ids
print("Weighted Loss Classification Report:")
print(classification_report(labels, preds, target_names=['Legitimate', 'Fraud']))
print("Weighted Loss Confusion Matrix:")
print(confusion_matrix(labels, preds))
# Out:
#     <div>
#
#       <progress value='888' max='888' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [888/888 01:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.395300</td>
#       <td>0.943834</td>
#       <td>0.888325</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.381600</td>
#       <td>0.428237</td>
#       <td>0.935702</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.410200</td>
#       <td>0.351159</td>
#       <td>0.950931</td>
#     </tr>
#   </tbody>
# </table><p>
# Weighted Loss Evaluation Results: {'eval_loss': 0.35115885734558105, 'eval_accuracy': 0.9509306260575296, 'eval_runtime': 1.2694, 'eval_samples_per_second': 465.587, 'eval_steps_per_second': 58.297, 'epoch': 3.0}
# Weighted Loss Classification Report:
#               precision    recall  f1-score   support
#
#   Legitimate       0.96      0.98      0.97       482
#        Fraud       0.91      0.82      0.86       109
#
#     accuracy                           0.95       591
#    macro avg       0.93      0.90      0.92       591
# weighted avg       0.95      0.95      0.95       591
#
# Weighted Loss Confusion Matrix:
# [[473   9]
#  [ 20  89]]

# %% [markdown]
# **Notes**:
#
# * **Model**: Starts from checkpoint-148 and retrains with weighted loss.
# * **Output**: Achieves app. 94% accuracy, 0.8 fraud recall, and 0.84 fraud precision (see output).
# * **Insight**: The combination of feature engineering and weighted loss resolves earlier issues, delivering robust performance.

# %% [markdown]
# # 11. Visualizations
#
# **Visualize Model Performance**
#
# **Purpose**: Visualizes the final model’s performance with confusion matrix, ROC curve, precision-recall curve, training loss plot, and feature distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve
import numpy as np
import torch

# Confusion Matrix Heatmap
cm = confusion_matrix(labels, preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Legitimate', 'Fraud'], yticklabels=['Legitimate', 'Fraud'])
plt.title('Confusion Matrix (Weighted Loss, Feature-Engineered)')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.savefig('confusion_matrix.png')
plt.show()

# ROC Curve
probs = torch.softmax(torch.tensor(predictions.predictions), dim=-1)[:, 1].numpy()
fpr, tpr, _ = roc_curve(labels, probs)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.savefig('roc_curve.png')
plt.show()

# Precision-Recall Curve
precision, recall, thresholds = precision_recall_curve(labels, probs)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.savefig('precision_recall_curve.png')
plt.show()

# Training Loss Plot
training_log = trainer.state.log_history
train_loss = [log['loss'] for log in training_log if 'loss' in log]
eval_loss = [log['eval_loss'] for log in training_log if 'eval_loss' in log]
epochs = range(1, len(eval_loss) + 1)
plt.figure(figsize=(8, 6))
plt.plot(epochs, train_loss[::len(train_loss)//len(epochs)], label='Training Loss')
plt.plot(epochs, eval_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.savefig('loss_plot.png')
plt.show()

# %% [markdown]
# **Notes**:
#
# * **ROC Curve**: High AUC (~0.95) indicates strong separability.
# * **Precision-Recall Curve**: Visualizes the recall-precision trade-off, critical for imbalanced datasets.
# * **Loss Plot**: Demonstrates model convergence over epochs.
# * **Feature Distribution**: Highlights differences in Amount between classes, justifying its inclusion in the text.

# %% [markdown]
# # Addressing the Accuracy Issue
#
# **Problem**
# Earlier runs achieved only ~81% accuracy, far below the target 93%.
# **Causes**
# 1. Class Imbalance: The initial model (81.22%) was biased toward legitimate transactions, with 0.17 fraud recall.
# 2. Checkpoint Mismatch: Evaluating checkpoint-296 on the feature-engineered dataset (64.13%) failed due to dataset incompatibility.
# 3. Training Instability: The first weighted loss attempt (64.81%) suffered from suboptimal convergence.
#
# **Fixes**
# 1. Weighted Loss: Applied 10x weight to fraud cases, improving fraud recall to 0.76.
# 2. Feature Engineering: Included V1–V8, enabling the model to capture richer patterns.
# 3. Retraining: Retrained on the feature-engineered dataset, achieving 92.89% accuracy.
# 4. Consistent Random Seeds: Used random_state=42 for reproducibility.
#
# **Validation**
# The final model consistently achieves ~93% accuracy when retrained on the feature-engineered dataset. If accuracy drops, verify checkpoints (!ls /kaggle/working/results_weighted) and retrain.

# %% [markdown]
# # How to Use This Model
#
# **Inference on New Data**
#
# **Purpose**: Predict fraud for new transactions using the trained model.

# %%
# Example new transaction
new_data = pd.DataFrame({
    'Time': [0.0],
    'Amount': [149.62],
    'V1': [-1.359807], 'V2': [-0.072781], 'V3': [2.536347], 'V4': [1.378155],
    'V5': [-0.338321], 'V6': [0.462388], 'V7': [0.239599], 'V8': [0.098698],
    'text': ['Transaction of $149.62 at time 0 seconds, V1=-1.36, V2=-0.07, V3=2.54, V4=1.38, V5=-0.34, V6=0.46, V7=0.24, V8=0.10']
})
new_dataset = Dataset.from_pandas(new_data)
new_dataset = new_dataset.map(tokenize_function, batched=True)
new_dataset.set_format('torch', columns=['input_ids', 'attention_mask'])

# Predict
predictions = trainer.predict(new_dataset)
probs = torch.softmax(torch.tensor(predictions.predictions), dim=-1).numpy()
pred = 'Fraud' if probs[0][1] >= 0.5 else 'Legitimate'

print(f"""Prediction: {pred}
Fraud probalbility: {probs[0][1]:.2f}
Legitimate probalbility: {probs[0][0]:.2f}
        """)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00, 169.75 examples/s]
# Prediction: Legitimate
# Fraud probalbility: 0.01
# Legitimate probalbility: 0.99

# %% [markdown]
# **Notes**:
#
# * Ensure the text column matches the feature-engineered format.
# * Use the final model (/kaggle/working/results_weighted).
#
#
#
# **Deployment**
#
# **Purpose**: Prepare the model for production use.

# %%
# Save model as ONNX

from transformers import DistilBertForSequenceClassification
import torch
model = DistilBertForSequenceClassification.from_pretrained('./results/checkpoint-296')
dummy_input = torch.zeros(1, 256, dtype=torch.long)
torch.onnx.export(model, dummy_input, "distilbert_fraud.onnx")
# Out:
# W0312 18:00:35.006000 2233878 site-packages/torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::nms
# W0312 18:00:35.008000 2233878 site-packages/torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::roi_align
# W0312 18:00:35.010000 2233878 site-packages/torch/onnx/_internal/exporter/_registration.py:110] torchvision is not installed. Skipping torchvision::roi_pool
# [torch.onnx] Obtain model graph for `DistilBertForSequenceClassification([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `DistilBertForSequenceClassification([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /data1/rachit/.conda/envs/cond/lib/python3.10/copyreg.py:101: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# Applied 6 of general pattern rewrite rules.
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 20},
#             producer_name='pytorch',
#             producer_version='2.10.0+cu128',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"input_ids"<INT64,[1,256]>
#             ),
#             outputs=(
#                 %"linear_37"<FLOAT,[1,2]>
#             ),
#             initializers=(
#                 %"distilbert.embeddings.word_embeddings.weight"<FLOAT,[30522,768]>{TorchTensor(...)},
#                 %"distilbert.embeddings.position_embeddings.weight"<FLOAT,[512,768]>{TorchTensor(...)},
#                 %"distilbert.embeddings.LayerNorm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.embeddings.LayerNorm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.attention.q_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.attention.k_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.attention.v_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.attention.out_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.sa_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.sa_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.ffn.lin1.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.ffn.lin2.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.output_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.0.output_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.attention.q_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.attention.k_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.attention.v_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.attention.out_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.sa_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.sa_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.ffn.lin1.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.ffn.lin2.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.output_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.1.output_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.attention.q_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.attention.k_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.attention.v_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.attention.out_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.sa_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.sa_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.ffn.lin1.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.ffn.lin2.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.output_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.2.output_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.attention.q_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.attention.k_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.attention.v_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.attention.out_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.sa_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.sa_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.ffn.lin1.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.ffn.lin2.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.output_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.3.output_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.attention.q_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.attention.k_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.attention.v_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.attention.out_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.sa_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.sa_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.ffn.lin1.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.ffn.lin2.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.output_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.4.output_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.attention.q_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.attention.k_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.attention.v_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.attention.out_lin.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.sa_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.sa_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.ffn.lin1.bias"<FLOAT,[3072]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.ffn.lin2.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.output_layer_norm.weight"<FLOAT,[768]>{TorchTensor(...)},
#                 %"distilbert.transformer.layer.5.output_layer_norm.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"pre_classifier.weight"<FLOAT,[768,768]>{TorchTensor(...)},
#                 %"pre_classifier.bias"<FLOAT,[768]>{TorchTensor(...)},
#                 %"classifier.weight"<FLOAT,[2,768]>{TorchTensor(...)},
#                 %"classifier.bias"<FLOAT,[2]>{TorchTensor<FLOAT,[2]>(Parameter containing: tensor([ 0.0003, -0.0003], requires_grad=True), name='classifier.bias')},
#                 %"slice_1"<INT64,[1,256]>{Tensor(...)},
#                 %"val_19"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_26"<INT64,[4]>{Tensor<INT64,[4]>(array([ 1, -1, 12, 64]), name='val_26')},
#                 %"val_27"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_35"<FLOAT,[768,768]>{Tensor(...)},
#                 %"view_3"<BOOL,[1,1,1,256]>{Tensor(...)},
#                 %"val_55"<INT64,[4]>{Tensor<INT64,[4]>(array([  1,  12, 256, 256]), name='val_55')},
#                 %"clone_1"<FLOAT,[]>{Tensor<FLOAT,[]>(array(-3.4028235e+38, dtype=float32), name='clone_1')},
#                 %"val_60"<INT64,[3]>{Tensor<INT64,[3]>(array([  1,  -1, 768]), name='val_60')},
#                 %"val_61"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_65"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_67"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_71"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_79"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_87"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_112"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_116"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_118"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_122"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_130"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_138"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_163"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_167"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_169"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_173"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_181"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_189"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_214"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_218"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_220"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_224"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_232"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_240"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_265"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_269"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_271"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_275"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_283"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_291"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_316"<FLOAT,[768,768]>{Tensor(...)},
#                 %"val_320"<FLOAT,[768,3072]>{Tensor(...)},
#                 %"val_322"<FLOAT,[3072,768]>{Tensor(...)},
#                 %"val_0"<INT64,[]>{Tensor<INT64,[]>(array(0), name='val_0')},
#                 %"val_43"<FLOAT,[]>{Tensor<FLOAT,[]>(array(8., dtype=float32), name='val_43')}
#             ),
#         ) {
#               0 |  # node_embedding
#                    %"embedding"<FLOAT,[1,256,768]> ⬅️ ::Gather(%"distilbert.embeddings.word_embeddings.weight"{...}, %"input_ids") {axis=0}
#               1 |  # node_embedding_1
#                    %"embedding_1"<FLOAT,[1,256,768]> ⬅️ ::Gather(%"distilbert.embeddings.position_embeddings.weight"{...}, %"slice_1"{...}) {axis=0}
#               2 |  # node_add
#                    %"add"<FLOAT,[1,256,768]> ⬅️ ::Add(%"embedding", %"embedding_1")
#               3 |  # node_layer_norm
#                    %"layer_norm"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add", %"distilbert.embeddings.LayerNorm.weight"{...}, %"distilbert.embeddings.LayerNorm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#               4 |  # node_MatMul_18
#                    %"val_20"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm", %"val_19"{...})
#               5 |  # node_linear
#                    %"linear"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_20", %"distilbert.transformer.layer.0.attention.q_lin.bias"{...})
#               6 |  # node_view
#                    %"view"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#               7 |  # node_transpose
#                    %"transpose"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view") {perm=(0, 2, 1, 3)}
#               8 |  # node_MatMul_26
#                    %"val_28"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm", %"val_27"{...})
#               9 |  # node_linear_1
#                    %"linear_1"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_28", %"distilbert.transformer.layer.0.attention.k_lin.bias"{...})
#              10 |  # node_view_1
#                    %"view_1"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_1", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              11 |  # node_MatMul_34
#                    %"val_36"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm", %"val_35"{...})
#              12 |  # node_linear_2
#                    %"linear_2"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_36", %"distilbert.transformer.layer.0.attention.v_lin.bias"{...})
#              13 |  # node_view_2
#                    %"view_2"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_2", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              14 |  # node_transpose_2
#                    %"transpose_2"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_2") {perm=(0, 2, 1, 3)}
#              15 |  # node_div
#                    %"div"<FLOAT,[1,12,256,64]> ⬅️ ::Div(%"transpose", %"val_43"{8.0})
#              16 |  # node_Transpose_305
#                    %"transpose_3"<FLOAT,[1,12,64,256]> ⬅️ ::Transpose(%"view_1") {perm=(0, 2, 3, 1)}
#              17 |  # node_matmul
#                    %"matmul"<FLOAT,[1,12,256,256]> ⬅️ ::MatMul(%"div", %"transpose_3")
#              18 |  # node_expand
#                    %"expand"<BOOL,[1,12,256,256]> ⬅️ ::Expand(%"view_3"{...}, %"val_55"{[1, 12, 256, 256]})
#              19 |  # node_masked_fill
#                    %"masked_fill"<FLOAT,[1,12,256,256]> ⬅️ ::Where(%"expand", %"clone_1"{-3.4028234663852886e+38}, %"matmul")
#              20 |  # node_softmax
#                    %"softmax"<FLOAT,[1,12,256,256]> ⬅️ ::Softmax(%"masked_fill") {axis=-1}
#              21 |  # node_matmul_1
#                    %"matmul_1"<FLOAT,[1,12,256,64]> ⬅️ ::MatMul(%"softmax", %"transpose_2")
#              22 |  # node_transpose_4
#                    %"transpose_4"<FLOAT,[1,256,12,64]> ⬅️ ::Transpose(%"matmul_1") {perm=(0, 2, 1, 3)}
#              23 |  # node_view_4
#                    %"view_4"<FLOAT,[1,256,768]> ⬅️ ::Reshape(%"transpose_4", %"val_60"{[1, -1, 768]}) {allowzero=1}
#              24 |  # node_MatMul_60
#                    %"val_62"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"view_4", %"val_61"{...})
#              25 |  # node_linear_3
#                    %"linear_3"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_62", %"distilbert.transformer.layer.0.attention.out_lin.bias"{...})
#              26 |  # node_add_1
#                    %"add_1"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_3", %"layer_norm")
#              27 |  # node_layer_norm_1
#                    %"layer_norm_1"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_1", %"distilbert.transformer.layer.0.sa_layer_norm.weight"{...}, %"distilbert.transformer.layer.0.sa_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#              28 |  # node_MatMul_62
#                    %"val_66"<FLOAT,[1,256,3072]> ⬅️ ::MatMul(%"layer_norm_1", %"val_65"{...})
#              29 |  # node_linear_4
#                    %"linear_4"<FLOAT,[1,256,3072]> ⬅️ ::Add(%"val_66", %"distilbert.transformer.layer.0.ffn.lin1.bias"{...})
#              30 |  # node_gelu
#                    %"gelu"<FLOAT,[1,256,3072]> ⬅️ ::Gelu(%"linear_4") {approximate='none'}
#              31 |  # node_MatMul_64
#                    %"val_68"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"gelu", %"val_67"{...})
#              32 |  # node_linear_5
#                    %"linear_5"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_68", %"distilbert.transformer.layer.0.ffn.lin2.bias"{...})
#              33 |  # node_add_2
#                    %"add_2"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_5", %"layer_norm_1")
#              34 |  # node_layer_norm_2
#                    %"layer_norm_2"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_2", %"distilbert.transformer.layer.0.output_layer_norm.weight"{...}, %"distilbert.transformer.layer.0.output_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#              35 |  # node_MatMul_66
#                    %"val_72"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_2", %"val_71"{...})
#              36 |  # node_linear_6
#                    %"linear_6"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_72", %"distilbert.transformer.layer.1.attention.q_lin.bias"{...})
#              37 |  # node_view_5
#                    %"view_5"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_6", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              38 |  # node_transpose_5
#                    %"transpose_5"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_5") {perm=(0, 2, 1, 3)}
#              39 |  # node_MatMul_74
#                    %"val_80"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_2", %"val_79"{...})
#              40 |  # node_linear_7
#                    %"linear_7"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_80", %"distilbert.transformer.layer.1.attention.k_lin.bias"{...})
#              41 |  # node_view_6
#                    %"view_6"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_7", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              42 |  # node_MatMul_82
#                    %"val_88"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_2", %"val_87"{...})
#              43 |  # node_linear_8
#                    %"linear_8"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_88", %"distilbert.transformer.layer.1.attention.v_lin.bias"{...})
#              44 |  # node_view_7
#                    %"view_7"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_8", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              45 |  # node_transpose_7
#                    %"transpose_7"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_7") {perm=(0, 2, 1, 3)}
#              46 |  # node_div_1
#                    %"div_1"<FLOAT,[1,12,256,64]> ⬅️ ::Div(%"transpose_5", %"val_43"{8.0})
#              47 |  # node_Transpose_306
#                    %"transpose_8"<FLOAT,[1,12,64,256]> ⬅️ ::Transpose(%"view_6") {perm=(0, 2, 3, 1)}
#              48 |  # node_matmul_2
#                    %"matmul_2"<FLOAT,[1,12,256,256]> ⬅️ ::MatMul(%"div_1", %"transpose_8")
#              49 |  # node_masked_fill_1
#                    %"masked_fill_1"<FLOAT,[1,12,256,256]> ⬅️ ::Where(%"expand", %"clone_1"{-3.4028234663852886e+38}, %"matmul_2")
#              50 |  # node_softmax_1
#                    %"softmax_1"<FLOAT,[1,12,256,256]> ⬅️ ::Softmax(%"masked_fill_1") {axis=-1}
#              51 |  # node_matmul_3
#                    %"matmul_3"<FLOAT,[1,12,256,64]> ⬅️ ::MatMul(%"softmax_1", %"transpose_7")
#              52 |  # node_transpose_9
#                    %"transpose_9"<FLOAT,[1,256,12,64]> ⬅️ ::Transpose(%"matmul_3") {perm=(0, 2, 1, 3)}
#              53 |  # node_view_9
#                    %"view_9"<FLOAT,[1,256,768]> ⬅️ ::Reshape(%"transpose_9", %"val_60"{[1, -1, 768]}) {allowzero=1}
#              54 |  # node_MatMul_107
#                    %"val_113"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"view_9", %"val_112"{...})
#              55 |  # node_linear_9
#                    %"linear_9"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_113", %"distilbert.transformer.layer.1.attention.out_lin.bias"{...})
#              56 |  # node_add_3
#                    %"add_3"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_9", %"layer_norm_2")
#              57 |  # node_layer_norm_3
#                    %"layer_norm_3"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_3", %"distilbert.transformer.layer.1.sa_layer_norm.weight"{...}, %"distilbert.transformer.layer.1.sa_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#              58 |  # node_MatMul_109
#                    %"val_117"<FLOAT,[1,256,3072]> ⬅️ ::MatMul(%"layer_norm_3", %"val_116"{...})
#              59 |  # node_linear_10
#                    %"linear_10"<FLOAT,[1,256,3072]> ⬅️ ::Add(%"val_117", %"distilbert.transformer.layer.1.ffn.lin1.bias"{...})
#              60 |  # node_gelu_1
#                    %"gelu_1"<FLOAT,[1,256,3072]> ⬅️ ::Gelu(%"linear_10") {approximate='none'}
#              61 |  # node_MatMul_111
#                    %"val_119"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"gelu_1", %"val_118"{...})
#              62 |  # node_linear_11
#                    %"linear_11"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_119", %"distilbert.transformer.layer.1.ffn.lin2.bias"{...})
#              63 |  # node_add_4
#                    %"add_4"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_11", %"layer_norm_3")
#              64 |  # node_layer_norm_4
#                    %"layer_norm_4"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_4", %"distilbert.transformer.layer.1.output_layer_norm.weight"{...}, %"distilbert.transformer.layer.1.output_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#              65 |  # node_MatMul_113
#                    %"val_123"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_4", %"val_122"{...})
#              66 |  # node_linear_12
#                    %"linear_12"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_123", %"distilbert.transformer.layer.2.attention.q_lin.bias"{...})
#              67 |  # node_view_10
#                    %"view_10"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_12", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              68 |  # node_transpose_10
#                    %"transpose_10"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_10") {perm=(0, 2, 1, 3)}
#              69 |  # node_MatMul_121
#                    %"val_131"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_4", %"val_130"{...})
#              70 |  # node_linear_13
#                    %"linear_13"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_131", %"distilbert.transformer.layer.2.attention.k_lin.bias"{...})
#              71 |  # node_view_11
#                    %"view_11"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_13", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              72 |  # node_MatMul_129
#                    %"val_139"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_4", %"val_138"{...})
#              73 |  # node_linear_14
#                    %"linear_14"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_139", %"distilbert.transformer.layer.2.attention.v_lin.bias"{...})
#              74 |  # node_view_12
#                    %"view_12"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_14", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              75 |  # node_transpose_12
#                    %"transpose_12"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_12") {perm=(0, 2, 1, 3)}
#              76 |  # node_div_2
#                    %"div_2"<FLOAT,[1,12,256,64]> ⬅️ ::Div(%"transpose_10", %"val_43"{8.0})
#              77 |  # node_Transpose_307
#                    %"transpose_13"<FLOAT,[1,12,64,256]> ⬅️ ::Transpose(%"view_11") {perm=(0, 2, 3, 1)}
#              78 |  # node_matmul_4
#                    %"matmul_4"<FLOAT,[1,12,256,256]> ⬅️ ::MatMul(%"div_2", %"transpose_13")
#              79 |  # node_masked_fill_2
#                    %"masked_fill_2"<FLOAT,[1,12,256,256]> ⬅️ ::Where(%"expand", %"clone_1"{-3.4028234663852886e+38}, %"matmul_4")
#              80 |  # node_softmax_2
#                    %"softmax_2"<FLOAT,[1,12,256,256]> ⬅️ ::Softmax(%"masked_fill_2") {axis=-1}
#              81 |  # node_matmul_5
#                    %"matmul_5"<FLOAT,[1,12,256,64]> ⬅️ ::MatMul(%"softmax_2", %"transpose_12")
#              82 |  # node_transpose_14
#                    %"transpose_14"<FLOAT,[1,256,12,64]> ⬅️ ::Transpose(%"matmul_5") {perm=(0, 2, 1, 3)}
#              83 |  # node_view_14
#                    %"view_14"<FLOAT,[1,256,768]> ⬅️ ::Reshape(%"transpose_14", %"val_60"{[1, -1, 768]}) {allowzero=1}
#              84 |  # node_MatMul_154
#                    %"val_164"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"view_14", %"val_163"{...})
#              85 |  # node_linear_15
#                    %"linear_15"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_164", %"distilbert.transformer.layer.2.attention.out_lin.bias"{...})
#              86 |  # node_add_5
#                    %"add_5"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_15", %"layer_norm_4")
#              87 |  # node_layer_norm_5
#                    %"layer_norm_5"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_5", %"distilbert.transformer.layer.2.sa_layer_norm.weight"{...}, %"distilbert.transformer.layer.2.sa_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#              88 |  # node_MatMul_156
#                    %"val_168"<FLOAT,[1,256,3072]> ⬅️ ::MatMul(%"layer_norm_5", %"val_167"{...})
#              89 |  # node_linear_16
#                    %"linear_16"<FLOAT,[1,256,3072]> ⬅️ ::Add(%"val_168", %"distilbert.transformer.layer.2.ffn.lin1.bias"{...})
#              90 |  # node_gelu_2
#                    %"gelu_2"<FLOAT,[1,256,3072]> ⬅️ ::Gelu(%"linear_16") {approximate='none'}
#              91 |  # node_MatMul_158
#                    %"val_170"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"gelu_2", %"val_169"{...})
#              92 |  # node_linear_17
#                    %"linear_17"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_170", %"distilbert.transformer.layer.2.ffn.lin2.bias"{...})
#              93 |  # node_add_6
#                    %"add_6"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_17", %"layer_norm_5")
#              94 |  # node_layer_norm_6
#                    %"layer_norm_6"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_6", %"distilbert.transformer.layer.2.output_layer_norm.weight"{...}, %"distilbert.transformer.layer.2.output_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#              95 |  # node_MatMul_160
#                    %"val_174"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_6", %"val_173"{...})
#              96 |  # node_linear_18
#                    %"linear_18"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_174", %"distilbert.transformer.layer.3.attention.q_lin.bias"{...})
#              97 |  # node_view_15
#                    %"view_15"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_18", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#              98 |  # node_transpose_15
#                    %"transpose_15"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_15") {perm=(0, 2, 1, 3)}
#              99 |  # node_MatMul_168
#                    %"val_182"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_6", %"val_181"{...})
#             100 |  # node_linear_19
#                    %"linear_19"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_182", %"distilbert.transformer.layer.3.attention.k_lin.bias"{...})
#             101 |  # node_view_16
#                    %"view_16"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_19", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             102 |  # node_MatMul_176
#                    %"val_190"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_6", %"val_189"{...})
#             103 |  # node_linear_20
#                    %"linear_20"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_190", %"distilbert.transformer.layer.3.attention.v_lin.bias"{...})
#             104 |  # node_view_17
#                    %"view_17"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_20", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             105 |  # node_transpose_17
#                    %"transpose_17"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_17") {perm=(0, 2, 1, 3)}
#             106 |  # node_div_3
#                    %"div_3"<FLOAT,[1,12,256,64]> ⬅️ ::Div(%"transpose_15", %"val_43"{8.0})
#             107 |  # node_Transpose_308
#                    %"transpose_18"<FLOAT,[1,12,64,256]> ⬅️ ::Transpose(%"view_16") {perm=(0, 2, 3, 1)}
#             108 |  # node_matmul_6
#                    %"matmul_6"<FLOAT,[1,12,256,256]> ⬅️ ::MatMul(%"div_3", %"transpose_18")
#             109 |  # node_masked_fill_3
#                    %"masked_fill_3"<FLOAT,[1,12,256,256]> ⬅️ ::Where(%"expand", %"clone_1"{-3.4028234663852886e+38}, %"matmul_6")
#             110 |  # node_softmax_3
#                    %"softmax_3"<FLOAT,[1,12,256,256]> ⬅️ ::Softmax(%"masked_fill_3") {axis=-1}
#             111 |  # node_matmul_7
#                    %"matmul_7"<FLOAT,[1,12,256,64]> ⬅️ ::MatMul(%"softmax_3", %"transpose_17")
#             112 |  # node_transpose_19
#                    %"transpose_19"<FLOAT,[1,256,12,64]> ⬅️ ::Transpose(%"matmul_7") {perm=(0, 2, 1, 3)}
#             113 |  # node_view_19
#                    %"view_19"<FLOAT,[1,256,768]> ⬅️ ::Reshape(%"transpose_19", %"val_60"{[1, -1, 768]}) {allowzero=1}
#             114 |  # node_MatMul_201
#                    %"val_215"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"view_19", %"val_214"{...})
#             115 |  # node_linear_21
#                    %"linear_21"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_215", %"distilbert.transformer.layer.3.attention.out_lin.bias"{...})
#             116 |  # node_add_7
#                    %"add_7"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_21", %"layer_norm_6")
#             117 |  # node_layer_norm_7
#                    %"layer_norm_7"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_7", %"distilbert.transformer.layer.3.sa_layer_norm.weight"{...}, %"distilbert.transformer.layer.3.sa_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#             118 |  # node_MatMul_203
#                    %"val_219"<FLOAT,[1,256,3072]> ⬅️ ::MatMul(%"layer_norm_7", %"val_218"{...})
#             119 |  # node_linear_22
#                    %"linear_22"<FLOAT,[1,256,3072]> ⬅️ ::Add(%"val_219", %"distilbert.transformer.layer.3.ffn.lin1.bias"{...})
#             120 |  # node_gelu_3
#                    %"gelu_3"<FLOAT,[1,256,3072]> ⬅️ ::Gelu(%"linear_22") {approximate='none'}
#             121 |  # node_MatMul_205
#                    %"val_221"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"gelu_3", %"val_220"{...})
#             122 |  # node_linear_23
#                    %"linear_23"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_221", %"distilbert.transformer.layer.3.ffn.lin2.bias"{...})
#             123 |  # node_add_8
#                    %"add_8"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_23", %"layer_norm_7")
#             124 |  # node_layer_norm_8
#                    %"layer_norm_8"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_8", %"distilbert.transformer.layer.3.output_layer_norm.weight"{...}, %"distilbert.transformer.layer.3.output_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#             125 |  # node_MatMul_207
#                    %"val_225"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_8", %"val_224"{...})
#             126 |  # node_linear_24
#                    %"linear_24"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_225", %"distilbert.transformer.layer.4.attention.q_lin.bias"{...})
#             127 |  # node_view_20
#                    %"view_20"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_24", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             128 |  # node_transpose_20
#                    %"transpose_20"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_20") {perm=(0, 2, 1, 3)}
#             129 |  # node_MatMul_215
#                    %"val_233"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_8", %"val_232"{...})
#             130 |  # node_linear_25
#                    %"linear_25"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_233", %"distilbert.transformer.layer.4.attention.k_lin.bias"{...})
#             131 |  # node_view_21
#                    %"view_21"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_25", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             132 |  # node_MatMul_223
#                    %"val_241"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_8", %"val_240"{...})
#             133 |  # node_linear_26
#                    %"linear_26"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_241", %"distilbert.transformer.layer.4.attention.v_lin.bias"{...})
#             134 |  # node_view_22
#                    %"view_22"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_26", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             135 |  # node_transpose_22
#                    %"transpose_22"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_22") {perm=(0, 2, 1, 3)}
#             136 |  # node_div_4
#                    %"div_4"<FLOAT,[1,12,256,64]> ⬅️ ::Div(%"transpose_20", %"val_43"{8.0})
#             137 |  # node_Transpose_309
#                    %"transpose_23"<FLOAT,[1,12,64,256]> ⬅️ ::Transpose(%"view_21") {perm=(0, 2, 3, 1)}
#             138 |  # node_matmul_8
#                    %"matmul_8"<FLOAT,[1,12,256,256]> ⬅️ ::MatMul(%"div_4", %"transpose_23")
#             139 |  # node_masked_fill_4
#                    %"masked_fill_4"<FLOAT,[1,12,256,256]> ⬅️ ::Where(%"expand", %"clone_1"{-3.4028234663852886e+38}, %"matmul_8")
#             140 |  # node_softmax_4
#                    %"softmax_4"<FLOAT,[1,12,256,256]> ⬅️ ::Softmax(%"masked_fill_4") {axis=-1}
#             141 |  # node_matmul_9
#                    %"matmul_9"<FLOAT,[1,12,256,64]> ⬅️ ::MatMul(%"softmax_4", %"transpose_22")
#             142 |  # node_transpose_24
#                    %"transpose_24"<FLOAT,[1,256,12,64]> ⬅️ ::Transpose(%"matmul_9") {perm=(0, 2, 1, 3)}
#             143 |  # node_view_24
#                    %"view_24"<FLOAT,[1,256,768]> ⬅️ ::Reshape(%"transpose_24", %"val_60"{[1, -1, 768]}) {allowzero=1}
#             144 |  # node_MatMul_248
#                    %"val_266"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"view_24", %"val_265"{...})
#             145 |  # node_linear_27
#                    %"linear_27"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_266", %"distilbert.transformer.layer.4.attention.out_lin.bias"{...})
#             146 |  # node_add_9
#                    %"add_9"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_27", %"layer_norm_8")
#             147 |  # node_layer_norm_9
#                    %"layer_norm_9"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_9", %"distilbert.transformer.layer.4.sa_layer_norm.weight"{...}, %"distilbert.transformer.layer.4.sa_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#             148 |  # node_MatMul_250
#                    %"val_270"<FLOAT,[1,256,3072]> ⬅️ ::MatMul(%"layer_norm_9", %"val_269"{...})
#             149 |  # node_linear_28
#                    %"linear_28"<FLOAT,[1,256,3072]> ⬅️ ::Add(%"val_270", %"distilbert.transformer.layer.4.ffn.lin1.bias"{...})
#             150 |  # node_gelu_4
#                    %"gelu_4"<FLOAT,[1,256,3072]> ⬅️ ::Gelu(%"linear_28") {approximate='none'}
#             151 |  # node_MatMul_252
#                    %"val_272"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"gelu_4", %"val_271"{...})
#             152 |  # node_linear_29
#                    %"linear_29"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_272", %"distilbert.transformer.layer.4.ffn.lin2.bias"{...})
#             153 |  # node_add_10
#                    %"add_10"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_29", %"layer_norm_9")
#             154 |  # node_layer_norm_10
#                    %"layer_norm_10"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_10", %"distilbert.transformer.layer.4.output_layer_norm.weight"{...}, %"distilbert.transformer.layer.4.output_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#             155 |  # node_MatMul_254
#                    %"val_276"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_10", %"val_275"{...})
#             156 |  # node_linear_30
#                    %"linear_30"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_276", %"distilbert.transformer.layer.5.attention.q_lin.bias"{...})
#             157 |  # node_view_25
#                    %"view_25"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_30", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             158 |  # node_transpose_25
#                    %"transpose_25"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_25") {perm=(0, 2, 1, 3)}
#             159 |  # node_MatMul_262
#                    %"val_284"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_10", %"val_283"{...})
#             160 |  # node_linear_31
#                    %"linear_31"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_284", %"distilbert.transformer.layer.5.attention.k_lin.bias"{...})
#             161 |  # node_view_26
#                    %"view_26"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_31", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             162 |  # node_MatMul_270
#                    %"val_292"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"layer_norm_10", %"val_291"{...})
#             163 |  # node_linear_32
#                    %"linear_32"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_292", %"distilbert.transformer.layer.5.attention.v_lin.bias"{...})
#             164 |  # node_view_27
#                    %"view_27"<FLOAT,[1,256,12,64]> ⬅️ ::Reshape(%"linear_32", %"val_26"{[1, -1, 12, 64]}) {allowzero=1}
#             165 |  # node_transpose_27
#                    %"transpose_27"<FLOAT,[1,12,256,64]> ⬅️ ::Transpose(%"view_27") {perm=(0, 2, 1, 3)}
#             166 |  # node_div_5
#                    %"div_5"<FLOAT,[1,12,256,64]> ⬅️ ::Div(%"transpose_25", %"val_43"{8.0})
#             167 |  # node_Transpose_310
#                    %"transpose_28"<FLOAT,[1,12,64,256]> ⬅️ ::Transpose(%"view_26") {perm=(0, 2, 3, 1)}
#             168 |  # node_matmul_10
#                    %"matmul_10"<FLOAT,[1,12,256,256]> ⬅️ ::MatMul(%"div_5", %"transpose_28")
#             169 |  # node_masked_fill_5
#                    %"masked_fill_5"<FLOAT,[1,12,256,256]> ⬅️ ::Where(%"expand", %"clone_1"{-3.4028234663852886e+38}, %"matmul_10")
#             170 |  # node_softmax_5
#                    %"softmax_5"<FLOAT,[1,12,256,256]> ⬅️ ::Softmax(%"masked_fill_5") {axis=-1}
#             171 |  # node_matmul_11
#                    %"matmul_11"<FLOAT,[1,12,256,64]> ⬅️ ::MatMul(%"softmax_5", %"transpose_27")
#             172 |  # node_transpose_29
#                    %"transpose_29"<FLOAT,[1,256,12,64]> ⬅️ ::Transpose(%"matmul_11") {perm=(0, 2, 1, 3)}
#             173 |  # node_view_29
#                    %"view_29"<FLOAT,[1,256,768]> ⬅️ ::Reshape(%"transpose_29", %"val_60"{[1, -1, 768]}) {allowzero=1}
#             174 |  # node_MatMul_295
#                    %"val_317"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"view_29", %"val_316"{...})
#             175 |  # node_linear_33
#                    %"linear_33"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_317", %"distilbert.transformer.layer.5.attention.out_lin.bias"{...})
#             176 |  # node_add_11
#                    %"add_11"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_33", %"layer_norm_10")
#             177 |  # node_layer_norm_11
#                    %"layer_norm_11"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_11", %"distilbert.transformer.layer.5.sa_layer_norm.weight"{...}, %"distilbert.transformer.layer.5.sa_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#             178 |  # node_MatMul_297
#                    %"val_321"<FLOAT,[1,256,3072]> ⬅️ ::MatMul(%"layer_norm_11", %"val_320"{...})
#             179 |  # node_linear_34
#                    %"linear_34"<FLOAT,[1,256,3072]> ⬅️ ::Add(%"val_321", %"distilbert.transformer.layer.5.ffn.lin1.bias"{...})
#             180 |  # node_gelu_5
#                    %"gelu_5"<FLOAT,[1,256,3072]> ⬅️ ::Gelu(%"linear_34") {approximate='none'}
#             181 |  # node_MatMul_299
#                    %"val_323"<FLOAT,[1,256,768]> ⬅️ ::MatMul(%"gelu_5", %"val_322"{...})
#             182 |  # node_linear_35
#                    %"linear_35"<FLOAT,[1,256,768]> ⬅️ ::Add(%"val_323", %"distilbert.transformer.layer.5.ffn.lin2.bias"{...})
#             183 |  # node_add_12
#                    %"add_12"<FLOAT,[1,256,768]> ⬅️ ::Add(%"linear_35", %"layer_norm_11")
#             184 |  # node_layer_norm_12
#                    %"layer_norm_12"<FLOAT,[1,256,768]> ⬅️ ::LayerNormalization(%"add_12", %"distilbert.transformer.layer.5.output_layer_norm.weight"{...}, %"distilbert.transformer.layer.5.output_layer_norm.bias"{...}) {stash_type=1, epsilon=1e-12, axis=-1}
#             185 |  # node_select
#                    %"select"<FLOAT,[1,768]> ⬅️ ::Gather(%"layer_norm_12", %"val_0"{0}) {axis=1}
#             186 |  # node_linear_36
#                    %"linear_36"<FLOAT,[1,768]> ⬅️ ::Gemm(%"select", %"pre_classifier.weight"{...}, %"pre_classifier.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             187 |  # node_relu
#                    %"relu"<FLOAT,[1,768]> ⬅️ ::Relu(%"linear_36")
#             188 |  # node_linear_37
#                    %"linear_37"<FLOAT,[1,2]> ⬅️ ::Gemm(%"relu", %"classifier.weight"{...}, %"classifier.bias"{[0.0003286041901446879, -0.00032860448118299246]}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             return %"linear_37"<FLOAT,[1,2]>
#         }
#
#
#     ,
#     exported_program=
#         ExportedProgram:
#             class GraphModule(torch.nn.Module):
#                 def forward(self, p_distilbert_embeddings_word_embeddings_weight: "f32[30522, 768]", p_distilbert_embeddings_position_embeddings_weight: "f32[512, 768]", p_distilbert_embeddings_layernorm_weight: "f32[768]", p_distilbert_embeddings_layernorm_bias: "f32[768]", p_distilbert_transformer_layer_0_attention_q_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_0_attention_q_lin_bias: "f32[768]", p_distilbert_transformer_layer_0_attention_k_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_0_attention_k_lin_bias: "f32[768]", p_distilbert_transformer_layer_0_attention_v_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_0_attention_v_lin_bias: "f32[768]", p_distilbert_transformer_layer_0_attention_out_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_0_attention_out_lin_bias: "f32[768]", p_distilbert_transformer_layer_0_sa_layer_norm_weight: "f32[768]", p_distilbert_transformer_layer_0_sa_layer_norm_bias: "f32[768]", p_distilbert_transformer_layer_0_ffn_lin1_weight: "f32[3072, 768]", p_distilbert_transformer_layer_0_ffn_lin1_bias: "f32[3072]", p_distilbert_transformer_layer_0_ffn_lin2_weight: "f32[768, 3072]", p_distilbert_transformer_layer_0_ffn_lin2_bias: "f32[768]", p_distilbert_transformer_layer_0_output_layer_norm_weight: "f32[768]", p_distilbert_transformer_layer_0_output_layer_norm_bias: "f32[768]", p_distilbert_transformer_layer_1_attention_q_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_1_attention_q_lin_bias: "f32[768]", p_distilbert_transformer_layer_1_attention_k_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_1_attention_k_lin_bias: "f32[768]", p_distilbert_transformer_layer_1_attention_v_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_1_attention_v_lin_bias: "f32[768]", p_distilbert_transformer_layer_1_attention_out_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_1_attention_out_lin_bias: "f32[768]", p_distilbert_transformer_layer_1_sa_layer_norm_weight: "f32[768]", p_distilbert_transformer_layer_1_sa_layer_norm_bias: "f32[768]", p_distilbert_transformer_layer_1_ffn_lin1_weight: "f32[3072, 768]", p_distilbert_transformer_layer_1_ffn_lin1_bias: "f32[3072]", p_distilbert_transformer_layer_1_ffn_lin2_weight: "f32[768, 3072]", p_distilbert_transformer_layer_1_ffn_lin2_bias: "f32[768]", p_distilbert_transformer_layer_1_output_layer_norm_weight: "f32[768]", p_distilbert_transformer_layer_1_output_layer_norm_bias: "f32[768]", p_distilbert_transformer_layer_2_attention_q_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_2_attention_q_lin_bias: "f32[768]", p_distilbert_transformer_layer_2_attention_k_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_2_attention_k_lin_bias: "f32[768]", p_distilbert_transformer_layer_2_attention_v_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_2_attention_v_lin_bias: "f32[768]", p_distilbert_transformer_layer_2_attention_out_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_2_attention_out_lin_bias: "f32[768]", p_distilbert_transformer_layer_2_sa_layer_norm_weight: "f32[768]", p_distilbert_transformer_layer_2_sa_layer_norm_bias: "f32[768]", p_distilbert_transformer_layer_2_ffn_lin1_weight: "f32[3072, 768]", p_distilbert_transformer_layer_2_ffn_lin1_bias: "f32[3072]", p_distilbert_transformer_layer_2_ffn_lin2_weight: "f32[768, 3072]", p_distilbert_transformer_layer_2_ffn_lin2_bias: "f32[768]", p_distilbert_transformer_layer_2_output_layer_norm_weight: "f32[768]", p_distilbert_transformer_layer_2_output_layer_norm_bias: "f32[768]", p_distilbert_transformer_layer_3_attention_q_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_3_attention_q_lin_bias: "f32[768]", p_distilbert_transformer_layer_3_attention_k_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_3_attention_k_lin_bias: "f32[768]", p_distilbert_transformer_layer_3_attention_v_lin_weight: "f32[768, 768]", p_distilbert_transformer_layer_3_attention_v_lin_bias: "f32[768]", p_distilbe ...
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/sparse.py:191 in forward, code: return F.embedding(
#                     embedding: "f32[1, 256, 768]" = torch.ops.aten.embedding.default(p_distilbert_embeddings_word_embeddings_weight, input_ids, 0);  p_distilbert_embeddings_word_embeddings_weight = input_ids = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:137 in forward, code: position_ids = self.position_ids[:, :seq_length]
#                     slice_1: "i64[1, 256]" = torch.ops.aten.slice.Tensor(b_distilbert_embeddings_position_ids, 1, 0, 256);  b_distilbert_embeddings_position_ids = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/sparse.py:191 in forward, code: return F.embedding(
#                     embedding_1: "f32[1, 256, 768]" = torch.ops.aten.embedding.default(p_distilbert_embeddings_position_embeddings_weight, slice_1);  p_distilbert_embeddings_position_embeddings_weight = slice_1 = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:144 in forward, code: embeddings = input_embeds + position_embeddings  # (bs, max_seq_length, dim)
#                     add: "f32[1, 256, 768]" = torch.ops.aten.add.Tensor(embedding, embedding_1);  embedding = embedding_1 = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/normalization.py:229 in forward, code: return F.layer_norm(
#                     layer_norm: "f32[1, 256, 768]" = torch.ops.aten.layer_norm.default(add, [768], p_distilbert_embeddings_layernorm_weight, p_distilbert_embeddings_layernorm_bias, 1e-12);  add = p_distilbert_embeddings_layernorm_weight = p_distilbert_embeddings_layernorm_bias = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/dropout.py:73 in forward, code: return F.dropout(input, self.p, self.training, self.inplace)
#                     clone: "f32[1, 256, 768]" = torch.ops.aten.clone.default(layer_norm);  layer_norm = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:812 in forward, code: attention_mask = torch.ones(input_shape, device=device)  # (bs, seq_length)
#                     ones: "f32[1, 256]" = torch.ops.aten.ones.default([1, 256], device = device(type='cpu'), pin_memory = False)
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear: "f32[1, 256, 768]" = torch.ops.aten.linear.default(clone, p_distilbert_transformer_layer_0_attention_q_lin_weight, p_distilbert_transformer_layer_0_attention_q_lin_bias);  p_distilbert_transformer_layer_0_attention_q_lin_weight = p_distilbert_transformer_layer_0_attention_q_lin_bias = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:226 in forward, code: q = shape(self.q_lin(query))  # (bs, n_heads, q_length, dim_per_head)
# ...
#                     relu: "f32[1, 768]" = torch.ops.aten.relu.default(linear_36);  linear_36 = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/dropout.py:73 in forward, code: return F.dropout(input, self.p, self.training, self.inplace)
#                     clone_25: "f32[1, 768]" = torch.ops.aten.clone.default(relu);  relu = None
#
#                     # File: /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_37: "f32[1, 2]" = torch.ops.aten.linear.default(clone_25, p_classifier_weight, p_classifier_bias);  clone_25 = p_classifier_weight = p_classifier_bias = None
#                     return (linear_37,)
#
#         Graph signature:
#             # inputs
#             p_distilbert_embeddings_word_embeddings_weight: PARAMETER target='distilbert.embeddings.word_embeddings.weight'
#             p_distilbert_embeddings_position_embeddings_weight: PARAMETER target='distilbert.embeddings.position_embeddings.weight'
#             p_distilbert_embeddings_layernorm_weight: PARAMETER target='distilbert.embeddings.LayerNorm.weight'
#             p_distilbert_embeddings_layernorm_bias: PARAMETER target='distilbert.embeddings.LayerNorm.bias'
#             p_distilbert_transformer_layer_0_attention_q_lin_weight: PARAMETER target='distilbert.transformer.layer.0.attention.q_lin.weight'
#             p_distilbert_transformer_layer_0_attention_q_lin_bias: PARAMETER target='distilbert.transformer.layer.0.attention.q_lin.bias'
#             p_distilbert_transformer_layer_0_attention_k_lin_weight: PARAMETER target='distilbert.transformer.layer.0.attention.k_lin.weight'
#             p_distilbert_transformer_layer_0_attention_k_lin_bias: PARAMETER target='distilbert.transformer.layer.0.attention.k_lin.bias'
#             p_distilbert_transformer_layer_0_attention_v_lin_weight: PARAMETER target='distilbert.transformer.layer.0.attention.v_lin.weight'
#             p_distilbert_transformer_layer_0_attention_v_lin_bias: PARAMETER target='distilbert.transformer.layer.0.attention.v_lin.bias'
#             p_distilbert_transformer_layer_0_attention_out_lin_weight: PARAMETER target='distilbert.transformer.layer.0.attention.out_lin.weight'
#             p_distilbert_transformer_layer_0_attention_out_lin_bias: PARAMETER target='distilbert.transformer.layer.0.attention.out_lin.bias'
#             p_distilbert_transformer_layer_0_sa_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.0.sa_layer_norm.weight'
#             p_distilbert_transformer_layer_0_sa_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.0.sa_layer_norm.bias'
#             p_distilbert_transformer_layer_0_ffn_lin1_weight: PARAMETER target='distilbert.transformer.layer.0.ffn.lin1.weight'
#             p_distilbert_transformer_layer_0_ffn_lin1_bias: PARAMETER target='distilbert.transformer.layer.0.ffn.lin1.bias'
#             p_distilbert_transformer_layer_0_ffn_lin2_weight: PARAMETER target='distilbert.transformer.layer.0.ffn.lin2.weight'
#             p_distilbert_transformer_layer_0_ffn_lin2_bias: PARAMETER target='distilbert.transformer.layer.0.ffn.lin2.bias'
#             p_distilbert_transformer_layer_0_output_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.0.output_layer_norm.weight'
#             p_distilbert_transformer_layer_0_output_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.0.output_layer_norm.bias'
#             p_distilbert_transformer_layer_1_attention_q_lin_weight: PARAMETER target='distilbert.transformer.layer.1.attention.q_lin.weight'
#             p_distilbert_transformer_layer_1_attention_q_lin_bias: PARAMETER target='distilbert.transformer.layer.1.attention.q_lin.bias'
#             p_distilbert_transformer_layer_1_attention_k_lin_weight: PARAMETER target='distilbert.transformer.layer.1.attention.k_lin.weight'
#             p_distilbert_transformer_layer_1_attention_k_lin_bias: PARAMETER target='distilbert.transformer.layer.1.attention.k_lin.bias'
#             p_distilbert_transformer_layer_1_attention_v_lin_weight: PARAMETER target='distilbert.transformer.layer.1.attention.v_lin.weight'
#             p_distilbert_transformer_layer_1_attention_v_lin_bias: PARAMETER target='distilbert.transformer.layer.1.attention.v_lin.bias'
#             p_distilbert_transformer_layer_1_attention_out_lin_weight: PARAMETER target='distilbert.transformer.layer.1.attention.out_lin.weight'
#             p_distilbert_transformer_layer_1_attention_out_lin_bias: PARAMETER target='distilbert.transformer.layer.1.attention.out_lin.bias'
#             p_distilbert_transformer_layer_1_sa_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.1.sa_layer_norm.weight'
#             p_distilbert_transformer_layer_1_sa_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.1.sa_layer_norm.bias'
#             p_distilbert_transformer_layer_1_ffn_lin1_weight: PARAMETER target='distilbert.transformer.layer.1.ffn.lin1.weight'
#             p_distilbert_transformer_layer_1_ffn_lin1_bias: PARAMETER target='distilbert.transformer.layer.1.ffn.lin1.bias'
#             p_distilbert_transformer_layer_1_ffn_lin2_weight: PARAMETER target='distilbert.transformer.layer.1.ffn.lin2.weight'
#             p_distilbert_transformer_layer_1_ffn_lin2_bias: PARAMETER target='distilbert.transformer.layer.1.ffn.lin2.bias'
#             p_distilbert_transformer_layer_1_output_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.1.output_layer_norm.weight'
#             p_distilbert_transformer_layer_1_output_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.1.output_layer_norm.bias'
#             p_distilbert_transformer_layer_2_attention_q_lin_weight: PARAMETER target='distilbert.transformer.layer.2.attention.q_lin.weight'
#             p_distilbert_transformer_layer_2_attention_q_lin_bias: PARAMETER target='distilbert.transformer.layer.2.attention.q_lin.bias'
#             p_distilbert_transformer_layer_2_attention_k_lin_weight: PARAMETER target='distilbert.transformer.layer.2.attention.k_lin.weight'
#             p_distilbert_transformer_layer_2_attention_k_lin_bias: PARAMETER target='distilbert.transformer.layer.2.attention.k_lin.bias'
#             p_distilbert_transformer_layer_2_attention_v_lin_weight: PARAMETER target='distilbert.transformer.layer.2.attention.v_lin.weight'
#             p_distilbert_transformer_layer_2_attention_v_lin_bias: PARAMETER target='distilbert.transformer.layer.2.attention.v_lin.bias'
#             p_distilbert_transformer_layer_2_attention_out_lin_weight: PARAMETER target='distilbert.transformer.layer.2.attention.out_lin.weight'
#             p_distilbert_transformer_layer_2_attention_out_lin_bias: PARAMETER target='distilbert.transformer.layer.2.attention.out_lin.bias'
#             p_distilbert_transformer_layer_2_sa_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.2.sa_layer_norm.weight'
#             p_distilbert_transformer_layer_2_sa_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.2.sa_layer_norm.bias'
#             p_distilbert_transformer_layer_2_ffn_lin1_weight: PARAMETER target='distilbert.transformer.layer.2.ffn.lin1.weight'
#             p_distilbert_transformer_layer_2_ffn_lin1_bias: PARAMETER target='distilbert.transformer.layer.2.ffn.lin1.bias'
#             p_distilbert_transformer_layer_2_ffn_lin2_weight: PARAMETER target='distilbert.transformer.layer.2.ffn.lin2.weight'
#             p_distilbert_transformer_layer_2_ffn_lin2_bias: PARAMETER target='distilbert.transformer.layer.2.ffn.lin2.bias'
#             p_distilbert_transformer_layer_2_output_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.2.output_layer_norm.weight'
#             p_distilbert_transformer_layer_2_output_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.2.output_layer_norm.bias'
#             p_distilbert_transformer_layer_3_attention_q_lin_weight: PARAMETER target='distilbert.transformer.layer.3.attention.q_lin.weight'
#             p_distilbert_transformer_layer_3_attention_q_lin_bias: PARAMETER target='distilbert.transformer.layer.3.attention.q_lin.bias'
#             p_distilbert_transformer_layer_3_attention_k_lin_weight: PARAMETER target='distilbert.transformer.layer.3.attention.k_lin.weight'
#             p_distilbert_transformer_layer_3_attention_k_lin_bias: PARAMETER target='distilbert.transformer.layer.3.attention.k_lin.bias'
#             p_distilbert_transformer_layer_3_attention_v_lin_weight: PARAMETER target='distilbert.transformer.layer.3.attention.v_lin.weight'
#             p_distilbert_transformer_layer_3_attention_v_lin_bias: PARAMETER target='distilbert.transformer.layer.3.attention.v_lin.bias'
#             p_distilbert_transformer_layer_3_attention_out_lin_weight: PARAMETER target='distilbert.transformer.layer.3.attention.out_lin.weight'
#             p_distilbert_transformer_layer_3_attention_out_lin_bias: PARAMETER target='distilbert.transformer.layer.3.attention.out_lin.bias'
#             p_distilbert_transformer_layer_3_sa_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.3.sa_layer_norm.weight'
#             p_distilbert_transformer_layer_3_sa_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.3.sa_layer_norm.bias'
#             p_distilbert_transformer_layer_3_ffn_lin1_weight: PARAMETER target='distilbert.transformer.layer.3.ffn.lin1.weight'
#             p_distilbert_transformer_layer_3_ffn_lin1_bias: PARAMETER target='distilbert.transformer.layer.3.ffn.lin1.bias'
#             p_distilbert_transformer_layer_3_ffn_lin2_weight: PARAMETER target='distilbert.transformer.layer.3.ffn.lin2.weight'
#             p_distilbert_transformer_layer_3_ffn_lin2_bias: PARAMETER target='distilbert.transformer.layer.3.ffn.lin2.bias'
#             p_distilbert_transformer_layer_3_output_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.3.output_layer_norm.weight'
#             p_distilbert_transformer_layer_3_output_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.3.output_layer_norm.bias'
#             p_distilbert_transformer_layer_4_attention_q_lin_weight: PARAMETER target='distilbert.transformer.layer.4.attention.q_lin.weight'
#             p_distilbert_transformer_layer_4_attention_q_lin_bias: PARAMETER target='distilbert.transformer.layer.4.attention.q_lin.bias'
#             p_distilbert_transformer_layer_4_attention_k_lin_weight: PARAMETER target='distilbert.transformer.layer.4.attention.k_lin.weight'
#             p_distilbert_transformer_layer_4_attention_k_lin_bias: PARAMETER target='distilbert.transformer.layer.4.attention.k_lin.bias'
#             p_distilbert_transformer_layer_4_attention_v_lin_weight: PARAMETER target='distilbert.transformer.layer.4.attention.v_lin.weight'
#             p_distilbert_transformer_layer_4_attention_v_lin_bias: PARAMETER target='distilbert.transformer.layer.4.attention.v_lin.bias'
#             p_distilbert_transformer_layer_4_attention_out_lin_weight: PARAMETER target='distilbert.transformer.layer.4.attention.out_lin.weight'
#             p_distilbert_transformer_layer_4_attention_out_lin_bias: PARAMETER target='distilbert.transformer.layer.4.attention.out_lin.bias'
#             p_distilbert_transformer_layer_4_sa_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.4.sa_layer_norm.weight'
#             p_distilbert_transformer_layer_4_sa_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.4.sa_layer_norm.bias'
#             p_distilbert_transformer_layer_4_ffn_lin1_weight: PARAMETER target='distilbert.transformer.layer.4.ffn.lin1.weight'
#             p_distilbert_transformer_layer_4_ffn_lin1_bias: PARAMETER target='distilbert.transformer.layer.4.ffn.lin1.bias'
#             p_distilbert_transformer_layer_4_ffn_lin2_weight: PARAMETER target='distilbert.transformer.layer.4.ffn.lin2.weight'
#             p_distilbert_transformer_layer_4_ffn_lin2_bias: PARAMETER target='distilbert.transformer.layer.4.ffn.lin2.bias'
#             p_distilbert_transformer_layer_4_output_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.4.output_layer_norm.weight'
#             p_distilbert_transformer_layer_4_output_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.4.output_layer_norm.bias'
#             p_distilbert_transformer_layer_5_attention_q_lin_weight: PARAMETER target='distilbert.transformer.layer.5.attention.q_lin.weight'
#             p_distilbert_transformer_layer_5_attention_q_lin_bias: PARAMETER target='distilbert.transformer.layer.5.attention.q_lin.bias'
#             p_distilbert_transformer_layer_5_attention_k_lin_weight: PARAMETER target='distilbert.transformer.layer.5.attention.k_lin.weight'
#             p_distilbert_transformer_layer_5_attention_k_lin_bias: PARAMETER target='distilbert.transformer.layer.5.attention.k_lin.bias'
#             p_distilbert_transformer_layer_5_attention_v_lin_weight: PARAMETER target='distilbert.transformer.layer.5.attention.v_lin.weight'
#             p_distilbert_transformer_layer_5_attention_v_lin_bias: PARAMETER target='distilbert.transformer.layer.5.attention.v_lin.bias'
#             p_distilbert_transformer_layer_5_attention_out_lin_weight: PARAMETER target='distilbert.transformer.layer.5.attention.out_lin.weight'
#             p_distilbert_transformer_layer_5_attention_out_lin_bias: PARAMETER target='distilbert.transformer.layer.5.attention.out_lin.bias'
#             p_distilbert_transformer_layer_5_sa_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.5.sa_layer_norm.weight'
#             p_distilbert_transformer_layer_5_sa_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.5.sa_layer_norm.bias'
#             p_distilbert_transformer_layer_5_ffn_lin1_weight: PARAMETER target='distilbert.transformer.layer.5.ffn.lin1.weight'
#             p_distilbert_transformer_layer_5_ffn_lin1_bias: PARAMETER target='distilbert.transformer.layer.5.ffn.lin1.bias'
#             p_distilbert_transformer_layer_5_ffn_lin2_weight: PARAMETER target='distilbert.transformer.layer.5.ffn.lin2.weight'
#             p_distilbert_transformer_layer_5_ffn_lin2_bias: PARAMETER target='distilbert.transformer.layer.5.ffn.lin2.bias'
#             p_distilbert_transformer_layer_5_output_layer_norm_weight: PARAMETER target='distilbert.transformer.layer.5.output_layer_norm.weight'
#             p_distilbert_transformer_layer_5_output_layer_norm_bias: PARAMETER target='distilbert.transformer.layer.5.output_layer_norm.bias'
#             p_pre_classifier_weight: PARAMETER target='pre_classifier.weight'
#             p_pre_classifier_bias: PARAMETER target='pre_classifier.bias'
#             p_classifier_weight: PARAMETER target='classifier.weight'
#             p_classifier_bias: PARAMETER target='classifier.bias'
#             b_distilbert_embeddings_position_ids: BUFFER target='distilbert.embeddings.position_ids' persistent=False
#             c_distilbert_transformer_layer_0_attention_lifted_tensor_0: CONSTANT_TENSOR target='distilbert.transformer.layer.0.attention.lifted_tensor_0'
#             c_distilbert_transformer_layer_1_attention_lifted_tensor_1: CONSTANT_TENSOR target='distilbert.transformer.layer.1.attention.lifted_tensor_1'
#             c_distilbert_transformer_layer_2_attention_lifted_tensor_2: CONSTANT_TENSOR target='distilbert.transformer.layer.2.attention.lifted_tensor_2'
#             c_distilbert_transformer_layer_3_attention_lifted_tensor_3: CONSTANT_TENSOR target='distilbert.transformer.layer.3.attention.lifted_tensor_3'
#             c_distilbert_transformer_layer_4_attention_lifted_tensor_4: CONSTANT_TENSOR target='distilbert.transformer.layer.4.attention.lifted_tensor_4'
#             c_distilbert_transformer_layer_5_attention_lifted_tensor_5: CONSTANT_TENSOR target='distilbert.transformer.layer.5.attention.lifted_tensor_5'
#             input_ids: USER_INPUT
#
#             # outputs
#             linear_37: USER_OUTPUT
#
#         Range constraints: {}
#
# )

# %% [markdown]
# **Notes**:
#
#
# * **ONNX**: Reduces inference latency for real-time applications.
# * **API**: Deploy with FastAPI or Flask for banking systems.
# * **Environment**: Use onnxruntime for cross-platform compatibility.
#
#
# **Evaluation**
#
#
# * **Metrics**: Prioritize fraud recall (>0.7) and monitor false negatives (26/109 in the final model).
# * **Threshold**: Adjust to ~0.1 for higher recall (e.g., 0.9), but note the accuracy trade-off (see threshold adjustment outputs).
# * **Validation**: Test on a holdout set to ensure generalization.

# %% [markdown]
# # 12. Extract Embeddings

# %% [markdown]
# ### Mean Pooling Embedding

# %%
import torch
from torch.utils.data import DataLoader
from datasets import concatenate_datasets
import numpy as np
import os
import pickle

def extract_mean_pooled_embeddings(train_dataset, test_dataset, model_path, tokenizer, batch_size=32, 
                                  output_dir='./embeddings'):
    """
    Extract mean-pooled embeddings from the fine-tuned model for both train and test datasets
    
    Args:
        train_dataset: Training dataset
        test_dataset: Test dataset
        model_path: Path to the fine-tuned model checkpoint
        tokenizer: Your existing tokenizer
        batch_size: Batch size for processing
        output_dir: Directory to save embeddings
        
    Returns:
        Dictionary containing embeddings, labels, and uids
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Load model from checkpoint
    from transformers import AutoModelForSequenceClassification
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = AutoModelForSequenceClassification.from_pretrained(model_path)
    model.to(device)
    model.eval()
    
    # 1) Combine train & test splits
    full_ds = concatenate_datasets([train_dataset, test_dataset])
    
    # 2) Ensure dataset has the necessary columns
    # If your tokenize_function is different from what's shown, adjust accordingly
    def tokenize_fn(examples):
        return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)
    
    # Check if dataset is already tokenized
    if 'input_ids' not in full_ds.column_names:
        embed_ds = full_ds.map(tokenize_fn, batched=True)
    else:
        embed_ds = full_ds
    
    # Ensure 'label' column is renamed to 'labels' if needed
    if 'label' in embed_ds.column_names and 'labels' not in embed_ds.column_names:
        embed_ds = embed_ds.rename_column("label", "labels")
    
    # Ensure 'uid' column exists, create if not
    if 'uid' not in embed_ds.column_names:
        embed_ds = embed_ds.map(lambda examples, indices: {'uid': indices}, with_indices=True, batched=True)
    
    # Set format for DataLoader
    columns = ['input_ids', 'attention_mask']
    if 'labels' in embed_ds.column_names:
        columns.append('labels')
    if 'uid' in embed_ds.column_names:
        columns.append('uid')
    
    embed_ds.set_format(type="torch", columns=columns)
    
    # 3) Create DataLoader
    loader = DataLoader(embed_ds, batch_size=batch_size, shuffle=False)
    
    # 4) Collect embeddings
    all_uids, all_labels, all_embs = [], [], []
    
    for batch in loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        
        if 'labels' in batch:
            labels = batch['labels'].tolist()
        else:
            labels = [-1] * len(input_ids)  # Placeholder if no labels
            
        if 'uid' in batch:
            uids = batch['uid'].tolist()
        else:
            uids = list(range(len(input_ids)))  # Generate sequential IDs if not available
        
        with torch.no_grad():
            # Extract the base model to get embeddings
            if hasattr(model, 'base_model'):
                out = model.base_model(input_ids=input_ids, attention_mask=attention_mask)
            else:
                # Access the model's backbone directly if base_model is not available
                out = model.transformer(input_ids=input_ids, attention_mask=attention_mask)
                
            last_hidden = out.last_hidden_state   # [batch, seq_len, hidden]
            
            # Calculate mean pooling embeddings
            mask = attention_mask.unsqueeze(-1)   # [batch, seq_len, 1]
            sum_emb = (last_hidden * mask).sum(dim=1)
            lengths = mask.sum(dim=1)
            mean_emb = sum_emb / lengths
            embs = mean_emb.cpu()
            
        all_uids.extend(uids)
        all_labels.extend(labels)
        all_embs.append(embs)
        
        # Print progress
        print(f"Processed batch, total embeddings so far: {len(all_uids)}")
    
    # Concatenate all embedding tensors
    all_embs_tensor = torch.cat(all_embs, dim=0)
    
    # Convert to numpy for storage
    all_embs_np = all_embs_tensor.numpy()
    
    # Create result dictionary
    result = {
        'embeddings': all_embs_np,
        'labels': all_labels,
        'uids': all_uids
    }
    
    # Save embeddings
    embeddings_path = os.path.join(output_dir, 'mean_pooled_embeddings.pkl')
    with open(embeddings_path, 'wb') as f:
        pickle.dump(result, f)
    
    print(f"Embeddings saved to {embeddings_path}")
    print(f"Embeddings shape: {all_embs_np.shape}")
    
    return result

# Example usage
def save_embeddings_for_model(train_dataset, test_dataset, tokenizer, model_path="./results/checkpoint-888"):
    """
    Extract and save embeddings for your model
    """
    result = extract_mean_pooled_embeddings(
        train_dataset, 
        test_dataset, 
        model_path,
        tokenizer
    )
    
    return result

# Function to load saved embeddings
def load_saved_embeddings(file_path='./embeddings/mean_pooled_embeddings.pkl'):
    """
    Load previously saved embeddings
    """
    with open(file_path, 'rb') as f:
        result = pickle.load(f)
    
    print(f"Loaded embeddings from {file_path}")
    print(f"Embeddings shape: {result['embeddings'].shape}")
    
    return result

# Optional: Split embeddings back into train and test sets
def split_embeddings(result, train_size):
    """
    Split combined embeddings back into train and test
    
    Args:
        result: Dictionary with embeddings, labels, uids
        train_size: Size of the training set
    
    Returns:
        Dictionary with train and test embeddings
    """
    train_embeddings = result['embeddings'][:train_size]
    test_embeddings = result['embeddings'][train_size:]
    
    train_labels = result['labels'][:train_size]
    test_labels = result['labels'][train_size:]
    
    train_uids = result['uids'][:train_size]
    test_uids = result['uids'][train_size:]
    
    return {
        'train': {
            'embeddings': train_embeddings,
            'labels': train_labels,
            'uids': train_uids
        },
        'test': {
            'embeddings': test_embeddings,
            'labels': test_labels,
            'uids': test_uids
        }
    }

# %%
# Extract and save embeddings
result = save_embeddings_for_model(
    train_dataset=train_dataset,
    test_dataset=test_dataset,
    tokenizer=tokenizer,
    model_path="./results/checkpoint-296"
)

# Later, load the embeddings
loaded_embeddings = load_saved_embeddings()

# If you need to split them back into train/test
train_size = len(train_dataset)
split_data = split_embeddings(loaded_embeddings, train_size)

# Access train or test embeddings
train_embs = split_data['train']['embeddings']
test_embs = split_data['test']['embeddings']
# Out:
# Map: 100%|██████████| 2952/2952 [00:00<00:00, 116861.43 examples/s]
# Processed batch, total embeddings so far: 32
# Processed batch, total embeddings so far: 64
# Processed batch, total embeddings so far: 96
# Processed batch, total embeddings so far: 128
# Processed batch, total embeddings so far: 160
# Processed batch, total embeddings so far: 192
# Processed batch, total embeddings so far: 224
# Processed batch, total embeddings so far: 256
# Processed batch, total embeddings so far: 288
# Processed batch, total embeddings so far: 320
# Processed batch, total embeddings so far: 352
# Processed batch, total embeddings so far: 384
# Processed batch, total embeddings so far: 416
# Processed batch, total embeddings so far: 448
# Processed batch, total embeddings so far: 480
# Processed batch, total embeddings so far: 512
# Processed batch, total embeddings so far: 544
# Processed batch, total embeddings so far: 576
# Processed batch, total embeddings so far: 608
# Processed batch, total embeddings so far: 640
# Processed batch, total embeddings so far: 672
# Processed batch, total embeddings so far: 704
# Processed batch, total embeddings so far: 736
# Processed batch, total embeddings so far: 768
# Processed batch, total embeddings so far: 800
# Processed batch, total embeddings so far: 832
# Processed batch, total embeddings so far: 864
# Processed batch, total embeddings so far: 896
# Processed batch, total embeddings so far: 928
# Processed batch, total embeddings so far: 960
# Processed batch, total embeddings so far: 992
# Processed batch, total embeddings so far: 1024
# Processed batch, total embeddings so far: 1056
# Processed batch, total embeddings so far: 1088
# Processed batch, total embeddings so far: 1120
# Processed batch, total embeddings so far: 1152
# Processed batch, total embeddings so far: 1184
# Processed batch, total embeddings so far: 1216
# Processed batch, total embeddings so far: 1248
# Processed batch, total embeddings so far: 1280
# Processed batch, total embeddings so far: 1312
# Processed batch, total embeddings so far: 1344
# Processed batch, total embeddings so far: 1376
# Processed batch, total embeddings so far: 1408
# Processed batch, total embeddings so far: 1440
# Processed batch, total embeddings so far: 1472
# Processed batch, total embeddings so far: 1504
# Processed batch, total embeddings so far: 1536
# Processed batch, total embeddings so far: 1568
# Processed batch, total embeddings so far: 1600
# Processed batch, total embeddings so far: 1632
# Processed batch, total embeddings so far: 1664
# Processed batch, total embeddings so far: 1696
# Processed batch, total embeddings so far: 1728
# Processed batch, total embeddings so far: 1760
# Processed batch, total embeddings so far: 1792
# Processed batch, total embeddings so far: 1824
# Processed batch, total embeddings so far: 1856
# Processed batch, total embeddings so far: 1888
# Processed batch, total embeddings so far: 1920
# Processed batch, total embeddings so far: 1952
# Processed batch, total embeddings so far: 1984
# Processed batch, total embeddings so far: 2016
# Processed batch, total embeddings so far: 2048
# Processed batch, total embeddings so far: 2080
# Processed batch, total embeddings so far: 2112
# Processed batch, total embeddings so far: 2144
# Processed batch, total embeddings so far: 2176
# Processed batch, total embeddings so far: 2208
# Processed batch, total embeddings so far: 2240
# Processed batch, total embeddings so far: 2272
# Processed batch, total embeddings so far: 2304
# Processed batch, total embeddings so far: 2336
# Processed batch, total embeddings so far: 2368
# Processed batch, total embeddings so far: 2400
# Processed batch, total embeddings so far: 2432
# Processed batch, total embeddings so far: 2464
# Processed batch, total embeddings so far: 2496
# Processed batch, total embeddings so far: 2528
# Processed batch, total embeddings so far: 2560
# Processed batch, total embeddings so far: 2592
# Processed batch, total embeddings so far: 2624
# Processed batch, total embeddings so far: 2656
# Processed batch, total embeddings so far: 2688
# Processed batch, total embeddings so far: 2720
# Processed batch, total embeddings so far: 2752
# Processed batch, total embeddings so far: 2784
# Processed batch, total embeddings so far: 2816
# Processed batch, total embeddings so far: 2848
# Processed batch, total embeddings so far: 2880
# Processed batch, total embeddings so far: 2912
# Processed batch, total embeddings so far: 2944
# Processed batch, total embeddings so far: 2952
# Embeddings saved to ./embeddings/mean_pooled_embeddings.pkl
# Embeddings shape: (2952, 768)
# Loaded embeddings from ./embeddings/mean_pooled_embeddings.pkl
# Embeddings shape: (2952, 768)

# %%
print(loaded_embeddings['embeddings'].shape)
# Out:
# (2952, 768)

# %% [markdown]
# ### Attention Based Pooling

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from datasets import concatenate_datasets
import os
import pickle


class AttentionPooling(nn.Module):
    """
    Learnable attention-based pooling layer that computes weighted combination of token embeddings
    """
    def __init__(self, hidden_size):
        super(AttentionPooling, self).__init__()
        self.attention = nn.Linear(hidden_size, 1)
    
    def forward(self, last_hidden_state, attention_mask):
        """
        Args:
            last_hidden_state: [batch, seq_len, hidden_size]
            attention_mask: [batch, seq_len]
        Returns:
            pooled_output: [batch, hidden_size]
        """
        # Calculate attention scores
        attention_scores = self.attention(last_hidden_state).squeeze(-1)  # [batch, seq_len]
        
        # Mask out padding tokens (set to large negative value before softmax)
        attention_scores = attention_scores.masked_fill(attention_mask == 0, -1e9)
        
        # Apply softmax to get attention weights
        attention_weights = torch.softmax(attention_scores, dim=1)  # [batch, seq_len]
        
        # Compute weighted sum
        pooled_output = torch.sum(last_hidden_state * attention_weights.unsqueeze(-1), dim=1)  # [batch, hidden_size]
        
        return pooled_output


def extract_attention_pooled_embeddings(train_dataset, test_dataset, model_path, tokenizer, batch_size=32,
                                       output_dir='./embeddings', hidden_size=768):
    """
    Extract attention-pooled embeddings from the fine-tuned model for both train and test datasets
    
    Args:
        train_dataset: Training dataset
        test_dataset: Test dataset
        model_path: Path to the fine-tuned model checkpoint
        tokenizer: Your existing tokenizer
        batch_size: Batch size for processing
        output_dir: Directory to save embeddings
        hidden_size: Hidden size of the model (768 for BERT-base, 1024 for BERT-large)
        
    Returns:
        Dictionary containing embeddings, labels, and uids
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Load model from checkpoint
    from transformers import AutoModelForSequenceClassification
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = AutoModelForSequenceClassification.from_pretrained(model_path)
    model.to(device)
    model.eval()
    
    # Initialize attention pooling layer
    attention_pooler = AttentionPooling(hidden_size).to(device)
    # Note: The attention layer starts with random weights. For better results, you could:
    # 1. Train it jointly with your model, or
    # 2. Fine-tune it on your task after model training
    attention_pooler.eval()
    
    # 1) Combine train & test splits
    full_ds = concatenate_datasets([train_dataset, test_dataset])
    
    # 2) Ensure dataset has the necessary columns
    def tokenize_fn(examples):
        return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)
    
    # Check if dataset is already tokenized
    if 'input_ids' not in full_ds.column_names:
        embed_ds = full_ds.map(tokenize_fn, batched=True)
    else:
        embed_ds = full_ds
    
    # Ensure 'label' column is renamed to 'labels' if needed
    if 'label' in embed_ds.column_names and 'labels' not in embed_ds.column_names:
        embed_ds = embed_ds.rename_column("label", "labels")
    
    # Ensure 'uid' column exists, create if not
    if 'uid' not in embed_ds.column_names:
        embed_ds = embed_ds.map(lambda examples, indices: {'uid': indices}, with_indices=True, batched=True)
    
    # Set format for DataLoader
    columns = ['input_ids', 'attention_mask']
    if 'labels' in embed_ds.column_names:
        columns.append('labels')
    if 'uid' in embed_ds.column_names:
        columns.append('uid')
    
    embed_ds.set_format(type="torch", columns=columns)
    
    # 3) Create DataLoader
    loader = DataLoader(embed_ds, batch_size=batch_size, shuffle=False)
    
    # 4) Collect embeddings
    all_uids, all_labels, all_embs = [], [], []
    
    for batch in loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        
        if 'labels' in batch:
            labels = batch['labels'].tolist()
        else:
            labels = [-1] * len(input_ids)  # Placeholder if no labels
            
        if 'uid' in batch:
            uids = batch['uid'].tolist()
        else:
            uids = list(range(len(input_ids)))  # Generate sequential IDs if not available
        
        with torch.no_grad():
            # Extract the base model to get embeddings
            if hasattr(model, 'base_model'):
                out = model.base_model(input_ids=input_ids, attention_mask=attention_mask)
            else:
                # Access the model's backbone directly if base_model is not available
                out = model.transformer(input_ids=input_ids, attention_mask=attention_mask)
                
            last_hidden = out.last_hidden_state   # [batch, seq_len, hidden]
            
            # Apply attention-based pooling
            pooled_emb = attention_pooler(last_hidden, attention_mask)
            embs = pooled_emb.cpu()
            
        all_uids.extend(uids)
        all_labels.extend(labels)
        all_embs.append(embs)
        
        # Print progress
        print(f"Processed batch, total embeddings so far: {len(all_uids)}")
    
    # Concatenate all embedding tensors
    all_embs_tensor = torch.cat(all_embs, dim=0)
    
    # Convert to numpy for storage
    all_embs_np = all_embs_tensor.numpy()
    
    # Create result dictionary
    result = {
        'embeddings': all_embs_np,
        'labels': all_labels,
        'uids': all_uids
    }
    
    # Save embeddings
    embeddings_path = os.path.join(output_dir, 'attention_pooled_embeddings.pkl')
    with open(embeddings_path, 'wb') as f:
        pickle.dump(result, f)
    
    print(f"Embeddings saved to {embeddings_path}")
    print(f"Embeddings shape: {all_embs_np.shape}")
    
    return result

# %%
# Extract attention-pooled embeddings
result = extract_attention_pooled_embeddings(
    train_dataset=train_dataset,
    test_dataset=test_dataset,
    tokenizer=tokenizer,
    model_path='./results_weighted/checkpoint-888'
)
# Out:
# Map: 100%|██████████| 2952/2952 [00:00<00:00, 144942.70 examples/s]
# Processed batch, total embeddings so far: 32
# Processed batch, total embeddings so far: 64
# Processed batch, total embeddings so far: 96
# Processed batch, total embeddings so far: 128
# Processed batch, total embeddings so far: 160
# Processed batch, total embeddings so far: 192
# Processed batch, total embeddings so far: 224
# Processed batch, total embeddings so far: 256
# Processed batch, total embeddings so far: 288
# Processed batch, total embeddings so far: 320
# Processed batch, total embeddings so far: 352
# Processed batch, total embeddings so far: 384
# Processed batch, total embeddings so far: 416
# Processed batch, total embeddings so far: 448
# Processed batch, total embeddings so far: 480
# Processed batch, total embeddings so far: 512
# Processed batch, total embeddings so far: 544
# Processed batch, total embeddings so far: 576
# Processed batch, total embeddings so far: 608
# Processed batch, total embeddings so far: 640
# Processed batch, total embeddings so far: 672
# Processed batch, total embeddings so far: 704
# Processed batch, total embeddings so far: 736
# Processed batch, total embeddings so far: 768
# Processed batch, total embeddings so far: 800
# Processed batch, total embeddings so far: 832
# Processed batch, total embeddings so far: 864
# Processed batch, total embeddings so far: 896
# Processed batch, total embeddings so far: 928
# Processed batch, total embeddings so far: 960
# Processed batch, total embeddings so far: 992
# Processed batch, total embeddings so far: 1024
# Processed batch, total embeddings so far: 1056
# Processed batch, total embeddings so far: 1088
# Processed batch, total embeddings so far: 1120
# Processed batch, total embeddings so far: 1152
# Processed batch, total embeddings so far: 1184
# Processed batch, total embeddings so far: 1216
# Processed batch, total embeddings so far: 1248
# Processed batch, total embeddings so far: 1280
# Processed batch, total embeddings so far: 1312
# Processed batch, total embeddings so far: 1344
# Processed batch, total embeddings so far: 1376
# Processed batch, total embeddings so far: 1408
# Processed batch, total embeddings so far: 1440
# Processed batch, total embeddings so far: 1472
# Processed batch, total embeddings so far: 1504
# Processed batch, total embeddings so far: 1536
# Processed batch, total embeddings so far: 1568
# Processed batch, total embeddings so far: 1600
# Processed batch, total embeddings so far: 1632
# Processed batch, total embeddings so far: 1664
# Processed batch, total embeddings so far: 1696
# Processed batch, total embeddings so far: 1728
# Processed batch, total embeddings so far: 1760
# Processed batch, total embeddings so far: 1792
# Processed batch, total embeddings so far: 1824
# Processed batch, total embeddings so far: 1856
# Processed batch, total embeddings so far: 1888
# Processed batch, total embeddings so far: 1920
# Processed batch, total embeddings so far: 1952
# Processed batch, total embeddings so far: 1984
# Processed batch, total embeddings so far: 2016
# Processed batch, total embeddings so far: 2048
# Processed batch, total embeddings so far: 2080
# Processed batch, total embeddings so far: 2112
# Processed batch, total embeddings so far: 2144
# Processed batch, total embeddings so far: 2176
# Processed batch, total embeddings so far: 2208
# Processed batch, total embeddings so far: 2240
# Processed batch, total embeddings so far: 2272
# Processed batch, total embeddings so far: 2304
# Processed batch, total embeddings so far: 2336
# Processed batch, total embeddings so far: 2368
# Processed batch, total embeddings so far: 2400
# Processed batch, total embeddings so far: 2432
# Processed batch, total embeddings so far: 2464
# Processed batch, total embeddings so far: 2496
# Processed batch, total embeddings so far: 2528
# Processed batch, total embeddings so far: 2560
# Processed batch, total embeddings so far: 2592
# Processed batch, total embeddings so far: 2624
# Processed batch, total embeddings so far: 2656
# Processed batch, total embeddings so far: 2688
# Processed batch, total embeddings so far: 2720
# Processed batch, total embeddings so far: 2752
# Processed batch, total embeddings so far: 2784
# Processed batch, total embeddings so far: 2816
# Processed batch, total embeddings so far: 2848
# Processed batch, total embeddings so far: 2880
# Processed batch, total embeddings so far: 2912
# Processed batch, total embeddings so far: 2944
# Processed batch, total embeddings so far: 2952
# Embeddings saved to ./embeddings/attention_pooled_embeddings.pkl
# Embeddings shape: (2952, 768)

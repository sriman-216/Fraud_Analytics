# %% [markdown]
# ## Tools and Libraries

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
import torch
import os

from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## The Custom Environment
#
# This class acts as the interface between the dataset and the SB3 agent.

# %%
class FraudDetectionEnv(gym.Env):
    """
    A custom Gym environment for Fraud Detection using embeddings.

    State: Embedding of a transaction.
    Action: 0 (Declare Not Fraud), 1 (Declare Fraud).
    Reward: Based on correctly/incorrectly classifying fraud vs non-fraud.
    """
    def __init__(self, embeddings: np.ndarray, labels: np.ndarray, reward_config: dict):
        super().__init__()

        # Ensure data consistency
        assert embeddings.shape[0] == labels.shape[0], "Embeddings and labels must have the same number of instances."
        assert embeddings.shape[1] == 768, f"Embeddings must be 768-dimensional, but got {embeddings.shape[1]}"

        self.embeddings = embeddings.astype(np.float32)
        self.labels = labels.astype(np.int64)

        self.num_instances = self.embeddings.shape[0]
        self.reward_config = reward_config

        # Define action and observation space
        # Action Space: Discrete(2) -> 0 for Not Fraud, 1 for Fraud
        self.action_space = spaces.Discrete(2)

        # Observation Space: Box(low, high, shape, dtype) -> 768-dim vector
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(768,), dtype=np.float32)

        # Internal state
        self._current_index = 0
        self._order = np.arange(self.num_instances)
        np.random.shuffle(self._order) # Shuffle the order of instances initially


    def step(self, action: int):
        # Check if episode is done
        if self._current_index >= self.num_instances:
            print("Warning: step() called when episode is already done.")
            return self.observation_space.sample() * 0, 0, True, False, {} # Return dummy values

        # Get current instance data based on shuffled order
        actual_index = self._order[self._current_index]
        current_embedding = self.embeddings[actual_index]
        true_label = self.labels[actual_index]

        # Determine reward
        reward = 0
        if action == 1 and true_label == 1:
            reward = self.reward_config.get('TP', 0)
        elif action == 1 and true_label == 0:
            reward = self.reward_config.get('FP', 0)
        elif action == 0 and true_label == 1:
            reward = self.reward_config.get('FN', 0)
        elif action == 0 and true_label == 0:
            reward = self.reward_config.get('TN', 0)

        # Move to the next instance
        self._current_index += 1

        # Check if the episode is finished
        done = self._current_index >= self.num_instances
        truncated = False

        # Get the next observation
        next_observation = np.zeros_like(current_embedding, dtype=np.float32) # Default for done state
        if not done:
             next_observation = self.embeddings[self._order[self._current_index]]

        info = {
            'true_label': true_label,
            'predicted_action': action,
            'instance_uid': actual_index,
            'is_done': done
        }

        return next_observation, reward, done, truncated, info


    def reset(self, seed=None, options=None):
        super().reset(seed=seed) # Handles seeding

        # Reset index and shuffle order for a new episode
        self._current_index = 0
        self._order = np.arange(self.num_instances)
        self.np_random.shuffle(self._order) # Use the environment's random number generator

        # Get the first observation of the new episode
        initial_observation = self.embeddings[self._order[self._current_index]]

        info = {'instance_uid': self._order[self._current_index]}

        return initial_observation, info

    def close(self):
        # Optional: Implement cleanup
        pass

# %% [markdown]
# ## Loading the Data (Embeddings)

# %%
data = pd.read_pickle("/home/rachit/COT/COT1/mini/Fraud_Analytics/embeddings/attention_pooled_embeddings.pkl")

# %%
embeddings = data['embeddings']
labels = np.array(data['labels'])

print(f"Embeddings: {embeddings.shape}")
print(f"True labels: {labels.shape}")
# Out:
# Embeddings: (2952, 768)
# True labels: (2952,)

# %%
embeddings_train, embeddings_test, labels_train, labels_test = train_test_split(
    embeddings, labels, test_size=0.2, random_state=42, stratify=labels
)

print(f"Training Embeddings shape: {embeddings_train.shape}")
print(f"Training Labels shape: {labels_train.shape}")

print(f"Testing Embeddings shape: {embeddings_test.shape}")
print(f"Testing Labels shape: {labels_test.shape}")

print("\nClass distribution in splits:")
print(f"Original: Fraud={np.mean(labels):.4f}")
print(f"Train:    Fraud={np.mean(labels_train):.4f}")
print(f"Test:     Fraud={np.mean(labels_test):.4f}")
# Out:
# Training Embeddings shape: (2361, 768)
# Training Labels shape: (2361,)
# Testing Embeddings shape: (591, 768)
# Testing Labels shape: (591,)
#
# Class distribution in splits:
# Original: Fraud=0.1667
# Train:    Fraud=0.1669
# Test:     Fraud=0.1658

# %% [markdown]
# ## Define Reward Configuration and Instantiate Environment
#
# Now we configure the rewards for the agent and create the environment instance.

# %%
reward_config = {
    'TP': 10.0,
    'FP': -5.0,
    'FN': -20.0,
    'TN': 1.0
}

print("Reward configuration:", reward_config)

# Create vectorized environment instance
n_envs = 8
train_env = make_vec_env(FraudDetectionEnv, env_kwargs={'embeddings': embeddings_train,
                                                        'labels': labels_train,
                                                        'reward_config': reward_config}, n_envs=n_envs, seed=0, vec_env_cls=SubprocVecEnv)


print("Training Environment created.")
print("Observation space:", train_env.observation_space)
print("Action space:", train_env.action_space)
# Out:
# Reward configuration: {'TP': 10.0, 'FP': -5.0, 'FN': -20.0, 'TN': 1.0}
# Training Environment created.
# Observation space: Box(-inf, inf, (768,), float32)
# Action space: Discrete(2)

# %% [markdown]
# ## Define and Train the DQN Agent
#
# We define the DQN model and start training.

# %%
tensorboard_log_dir = "./dqn_fraud_tb/"

# %%
# Define a learning rate schedule
def linear_schedule(initial_value):
    def schedule(progress_remaining):
        return progress_remaining * initial_value
    return schedule

# %%
# Define the DQN model with MLP and scheduled learning rate
model = DQN("MlpPolicy",
            train_env,
            learning_rate=linear_schedule(1e-4),  # Use the schedule here
            buffer_size=100000,  # Size of the replay buffer
            learning_starts=1000, # Number of steps before learning starts (buffer needs data)
            batch_size=512,      # Minibatch size for gradient updates
            gamma=0.99,         # Discount factor
            train_freq=1,       # Train the model after each episode step
            gradient_steps=1,   # Number of gradient steps per training iteration
            target_update_interval=500, # Update the target network every N steps
            exploration_fraction=0.1, # Fraction of total timesteps for exploration phase
            exploration_initial_eps=1.0, # Initial epsilon value
            exploration_final_eps=0.05,  # Final epsilon value
            max_grad_norm=10,   # Clip gradients to avoid instability
            verbose=1,          # Print training information
            device="auto",      # Use GPU if available, otherwise CPU
            tensorboard_log=tensorboard_log_dir, # Log to TensorBoard
           )

print("DQN model created.")
# Out:
# Using cuda device
# DQN model created.

# %%
total_episodes = 100 # Train for number passes through the data
total_timesteps = total_episodes * embeddings_train.shape[0]

print(f"Total episodes: {total_episodes}")
print(f"Total timesteps: {total_timesteps}")
# Out:
# Total episodes: 100
# Total timesteps: 236100

# %%
checkpoint_log_dir = "./dqn_fraud_checkpoints/" 
os.makedirs(checkpoint_log_dir, exist_ok=True)

checkpoint_callback = CheckpointCallback(save_freq=10000, save_path=checkpoint_log_dir, name_prefix='dqn_fraud_model')

# %%
# !pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=0.4 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (3.10.2)
# Requirement already satisfied: numpy>=1.12.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (2.2.6)
# Requirement already satisfied: packaging in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (12.1.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (80.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from tensorboard) (3.1.6)
# Requirement already satisfied: typing-extensions~=4.12 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)

# %%
# Train the model
model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)

print("Training finished.")
# Out:
# Logging to ./dqn_fraud_tb/DQN_1
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 2.36e+03  |
# |    ep_rew_mean      | -1.91e+03 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 1286      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 18888     |
# | train/              |           |
# |    learning_rate    | 9.2e-05   |
# |    loss             | 2.25      |
# |    n_updates        | 2235      |
# -----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.36e+03  |
# |    ep_rew_mean     | -1.91e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 1285      |
# |    time_elapsed    | 14        |
# |    total_timesteps | 18888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 760      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1207     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 37776    |
# | train/              |          |
# |    learning_rate    | 8.4e-05  |
# |    loss             | 1.98     |
# |    n_updates        | 4596     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 760      |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 1207     |
# |    time_elapsed    | 31       |
# |    total_timesteps | 37776    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 1.76e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1248     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 56664    |
# | train/              |          |
# |    learning_rate    | 7.6e-05  |
# |    loss             | 1.85     |
# |    n_updates        | 6957     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 1.76e+03 |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 1247     |
# |    time_elapsed    | 45       |
# |    total_timesteps | 56664    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 2.26e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1266     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 75552    |
# | train/              |          |
# |    learning_rate    | 6.8e-05  |
# |    loss             | 1.73     |
# |    n_updates        | 9318     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 2.26e+03 |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 1266     |
# |    time_elapsed    | 59       |
# |    total_timesteps | 75552    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 2.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1283     |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 94440    |
# | train/              |          |
# |    learning_rate    | 6e-05    |
# |    loss             | 1.88     |
# |    n_updates        | 11679    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 2.58e+03 |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 1283     |
# |    time_elapsed    | 73       |
# |    total_timesteps | 94440    |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 2.79e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1293     |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 113328   |
# | train/              |          |
# |    learning_rate    | 5.2e-05  |
# |    loss             | 1.56     |
# |    n_updates        | 14040    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 2.79e+03 |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 1293     |
# |    time_elapsed    | 87       |
# |    total_timesteps | 113328   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 2.95e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1306     |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 132216   |
# | train/              |          |
# |    learning_rate    | 4.4e-05  |
# |    loss             | 2.04     |
# |    n_updates        | 16401    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 2.95e+03 |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 1306     |
# |    time_elapsed    | 101      |
# |    total_timesteps | 132216   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 3.1e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1329     |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 151104   |
# | train/              |          |
# |    learning_rate    | 3.6e-05  |
# |    loss             | 2        |
# |    n_updates        | 18762    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 3.1e+03  |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 1329     |
# |    time_elapsed    | 113      |
# |    total_timesteps | 151104   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 3.2e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1330     |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 169992   |
# | train/              |          |
# |    learning_rate    | 2.8e-05  |
# |    loss             | 1.83     |
# |    n_updates        | 21123    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 3.2e+03  |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 1330     |
# |    time_elapsed    | 127      |
# |    total_timesteps | 169992   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 3.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1342     |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 188880   |
# | train/              |          |
# |    learning_rate    | 2e-05    |
# |    loss             | 1.65     |
# |    n_updates        | 23484    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 3.3e+03  |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 1342     |
# |    time_elapsed    | 140      |
# |    total_timesteps | 188880   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 3.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1349     |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 207768   |
# | train/              |          |
# |    learning_rate    | 1.2e-05  |
# |    loss             | 1.86     |
# |    n_updates        | 25845    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 3.38e+03 |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 1349     |
# |    time_elapsed    | 153      |
# |    total_timesteps | 207768   |
# ---------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.36e+03 |
# |    ep_rew_mean      | 3.45e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1345     |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 226656   |
# | train/              |          |
# |    learning_rate    | 4e-06    |
# |    loss             | 2.29     |
# |    n_updates        | 28206    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.36e+03 |
# |    ep_rew_mean     | 3.45e+03 |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 1345     |
# |    time_elapsed    | 168      |
# |    total_timesteps | 226656   |
# ---------------------------------
# Training finished.

# %% [markdown]
# ## Evaluate the Trained DQN Agent
#
# After training, we want to see how well the agent performs. We'll run it without exploration
#
#
#
# **Note: We create a separate environment instance using the test data and run the evaluation loop on it.**

# %%
eval_env = make_vec_env(FraudDetectionEnv,
                        env_kwargs={'embeddings': embeddings_test,
                                    'labels': labels_test,
                                    'reward_config': reward_config},
                        n_envs=1,
                        seed=43)
print("Evaluation Environment created")
# Out:
# Evaluation Environment created

# %%
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import time
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import io
from PIL import Image
import torch
import os


eval_log_dir = os.path.join(tensorboard_log_dir, "evaluation", f"eval_{time.strftime('%Y%m%d-%H%M%S')}")
writer = SummaryWriter(eval_log_dir)
print(f"TensorBoard logs will be saved to: {eval_log_dir}")

rewards_over_time = []

# Reset the environment for evaluation
obs = eval_env.reset()
done = False
total_reward = 0
predicted_labels = []
true_labels = []
instance_uids = []
episode_steps = 0
all_q_values = []
rewards_over_time = []  # Track rewards for plotting

# Use deterministic=True to turn off exploration (epsilon = 0)
while not done:
    # For Stable Baselines3 DQN, we can access q_values directly
    with torch.no_grad():
        # Convert observation to tensor
        obs_tensor = torch.FloatTensor(obs).to(model.device)
        # Get q_values using SB3's policy (this works for DQN)
        q_values = model.q_net(obs_tensor).detach().cpu().numpy()
    
    all_q_values.append(q_values)
    
    # Predict action
    action, _ = model.predict(obs, deterministic=True)
    action = action[0]
    
    # Step the environment
    obs, reward, done_flags, infos = eval_env.step([action])
    
    # Extract info for the single environment
    info = infos[0]
    done = done_flags[0]
    reward_value = reward[0]  # Reward is also a batch for VecEnv
    total_reward += reward_value
    rewards_over_time.append(reward_value)  # Store reward for plotting
    
    # Store results
    predicted_labels.append(action)
    true_labels.append(info['true_label'])
    instance_uids.append(info['instance_uid'])
    
    # Log immediate reward for this step
    writer.add_scalar('Evaluation/Step_Reward', reward_value, episode_steps)
    
    # Log Q-values for this step
    for i, q_val in enumerate(q_values[0]):
        writer.add_scalar(f'Evaluation/Q_Value_Action_{i}', q_val, episode_steps)
    
    # Log max Q-value
    writer.add_scalar('Evaluation/Max_Q_Value', np.max(q_values), episode_steps)
    
    # Log the chosen action
    writer.add_scalar('Evaluation/Action_Taken', action, episode_steps)
    
    episode_steps += 1
# Out:
# TensorBoard logs will be saved to: ./dqn_fraud_tb/evaluation/eval_20260227-122158

# %%
# Compute accuracy
accuracy = np.mean(np.array(predicted_labels) == np.array(true_labels))
writer.add_scalar('Evaluation/Accuracy', accuracy, 0)
writer.add_scalar('Evaluation/Total_Reward', total_reward, 0)
writer.add_scalar('Evaluation/Steps', episode_steps, 0)

# Create and log confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))  # Convert to CHW format
writer.add_image('Evaluation/Confusion_Matrix', img_tensor, 0)
plt.close()

# Log detailed classification metrics
class_names = [f"Class_{i}" for i in range(max(max(true_labels), max(predicted_labels)) + 1)]
report = classification_report(true_labels, predicted_labels, target_names=class_names)
writer.add_text('Evaluation/Classification_Report', '```\n' + report + '\n```', 0)

# Add class-wise metrics
for cls in range(len(class_names)):
    # Calculate class precision and recall
    true_positives = sum(1 for true, pred in zip(true_labels, predicted_labels) if true == cls and pred == cls)
    predicted_as_cls = sum(1 for pred in predicted_labels if pred == cls)
    actual_cls = sum(1 for true in true_labels if true == cls)
    
    precision = true_positives / predicted_as_cls if predicted_as_cls > 0 else 0
    recall = true_positives / actual_cls if actual_cls > 0 else 0
    
    writer.add_scalar(f'Evaluation/Class_{cls}_Precision', precision, 0)
    writer.add_scalar(f'Evaluation/Class_{cls}_Recall', recall, 0)

# Visualize average Q-values across the episode
all_q_values = np.array(all_q_values)
avg_q_values = np.mean(all_q_values, axis=0)[0]  # Average across steps
writer.add_scalar('Evaluation/Average_Max_Q_Value', np.max(avg_q_values), 0)

# Create bar plot of average Q-values
plt.figure(figsize=(10, 6))
plt.bar(range(len(avg_q_values)), avg_q_values)
plt.xlabel('Actions')
plt.ylabel('Average Q-Value')
plt.title('Average Q-Values Per Action')

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Average_Q_Values', img_tensor, 0)
plt.close()

# Create a plot of rewards over time
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(len(rewards_over_time)), rewards_over_time)
plt.xlabel('Step')
plt.ylabel('Step Reward')
plt.title('Rewards Per Step During Evaluation')
plt.grid(True)

plt.subplot(1, 2, 2)
cumulative_rewards = np.cumsum(rewards_over_time)
plt.plot(range(len(cumulative_rewards)), cumulative_rewards)
plt.xlabel('Step')
plt.ylabel('Cumulative Reward')
plt.title('Cumulative Reward During Evaluation')
plt.grid(True)

plt.tight_layout()

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Reward_Analysis', img_tensor, 0)
plt.close()

# Close the writer
writer.close()

print(f"Evaluation finished. Total reward: {total_reward}")
print(f"Accuracy: {accuracy:.4f}")
print(f"TensorBoard logs saved to {eval_log_dir}")
# Out:
# Evaluation finished. Total reward: 945.0
# Accuracy: 0.9459
# TensorBoard logs saved to ./dqn_fraud_tb/evaluation/eval_20260227-122158

# %%
# Reset the environment for evaluation
# The environment will shuffle the data again for the evaluation run
obs = eval_env.reset()
done = False
total_reward = 0

predicted_labels = []
true_labels = []
instance_uids = []


# Use deterministic=True to turn off exploration (epsilon = 0)
while not done:

    action, _ = model.predict(obs, deterministic=True)

    action = action[0]

    # Step the environment
    obs, reward, done_flags, infos = eval_env.step([action])

    # Extract info for the single environment
    info = infos[0]
    done = done_flags[0]

    total_reward += reward[0] # Reward is also a batch for VecEnv

    # Store results
    predicted_labels.append(action)
    true_labels.append(info['true_label'])
    instance_uids.append(info['instance_uid'])

print(f"Evaluation finished. Total reward: {total_reward}")
# Out:
# Evaluation finished. Total reward: 945.0

# %%
predicted_labels = np.array(predicted_labels)
true_labels = np.array(true_labels)


cm = confusion_matrix(true_labels, predicted_labels)

TN, FP, FN, TP = cm.ravel() if cm.size == 4 else (0,0,0,0)

print("\n--- Classification Metrics ---")
print("Confusion Matrix:")
print(f"TP: {TP}, FP: {FP}, FN: {FN}, TN: {TN}")


#plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# --- Classification Metrics ---
# Confusion Matrix:
# TP: 84, FP: 18, FN: 14, TN: 475

# %%
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, zero_division=0)
recall = recall_score(true_labels, predicted_labels, zero_division=0)
f1 = f1_score(true_labels, predicted_labels, zero_division=0)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (Class 1 - Fraud): {precision:.4f}")
print(f"Recall (Class 1 - Fraud): {recall:.4f}")
print(f"F1 Score (Class 1 - Fraud): {f1:.4f}")
# Out:
# Accuracy: 0.9459
# Precision (Class 1 - Fraud): 0.8235
# Recall (Class 1 - Fraud): 0.8571
# F1 Score (Class 1 - Fraud): 0.8400

# %% [markdown]
# Saving the Model

# %%
model_save_path = "models/dqn_fraud_model"
model.save(model_save_path)
print(f"\nModel saved to {model_save_path}")
# Out:
# Model saved to models/dqn_fraud_model
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:284: UserWarning: Path 'models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %% [markdown]
# ## THE ACTOR CRITIC MODEL

# %%
from stable_baselines3 import A2C

# %%
tensorboard_log_dir2 = "./a2c_fraud_tb/"
train_env.reset()
print("Training Environment reset.")
# Out:
# Training Environment reset.

# %%
checkpoint_log_dir2 = "./a2c_fraud_checkpoints/" 
os.makedirs(checkpoint_log_dir2, exist_ok=True)

checkpoint_callback2 = CheckpointCallback(save_freq=10000, save_path=checkpoint_log_dir2, name_prefix='A2C_fraud_model')

# %%
# Define the A2C model with MLP policy
ac_model = A2C(
    "MlpPolicy",
    train_env,
    learning_rate=1e-4,
    gamma=0.99,          # discount factor
    n_steps=5,           # how many steps to run for each update
    ent_coef=0.01,       # entropy bonus
    vf_coef=0.5,         # value function loss coefficient
    max_grad_norm=0.5,   # gradient clipping
    verbose=1,           # print training info
    device="auto",        # GPU if available
    tensorboard_log=tensorboard_log_dir2, # log to TensorBoard
    
)
print("A2C model created.")
# Out:
# Using cuda device
# A2C model created.
# /data1/rachit/.conda/envs/cond/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Reuse the same total_timesteps you set for DQN
ac_model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback2)
print("A2C training finished.")
# Out:
# Logging to ./a2c_fraud_tb/A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 1815     |
# |    iterations         | 100      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.331   |
# |    explained_variance | 0.11     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.709    |
# |    value_loss         | 71.6     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1965     |
# |    iterations         | 200      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -0.184   |
# |    explained_variance | 0.068    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.228   |
# |    value_loss         | 39.2     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 2018      |
# |    iterations         | 300       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -0.13     |
# |    explained_variance | -0.000297 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 299       |
# |    policy_loss        | 0.342     |
# |    value_loss         | 38        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 2052     |
# |    iterations         | 400      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.125   |
# |    explained_variance | 0.000165 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.314   |
# |    value_loss         | 104      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 2.49e+03 |
# | time/                 |          |
# |    fps                | 2071     |
# |    iterations         | 500      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0761  |
# |    explained_variance | 0.000154 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.552    |
# |    value_loss         | 42       |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 2.49e+03  |
# | time/                 |           |
# |    fps                | 2079      |
# |    iterations         | 600       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -0.0541   |
# |    explained_variance | -0.000267 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.0102    |
# |    value_loss         | 83        |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 2.49e+03 |
# | time/                 |          |
# |    fps                | 2087     |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.0713  |
# |    explained_variance | 2.38e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.154    |
# |    value_loss         | 58.6     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 2.49e+03  |
# | time/                 |           |
# |    fps                | 2099      |
# |    iterations         | 800       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -0.0345   |
# |    explained_variance | -6.12e-05 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 799       |
# |    policy_loss        | 0.769     |
# |    value_loss         | 101       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 2.49e+03  |
# | time/                 |           |
# |    fps                | 2104      |
# |    iterations         | 900       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -0.0498   |
# |    explained_variance | -2.73e-05 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 899       |
# |    policy_loss        | -0.00875  |
# |    value_loss         | 57.9      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.2e+03  |
# | time/                 |          |
# |    fps                | 2107     |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.0224  |
# |    explained_variance | 1.94e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0101   |
# |    value_loss         | 41.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.2e+03  |
# | time/                 |          |
# |    fps                | 2110     |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.0484  |
# |    explained_variance | 3.58e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.175   |
# |    value_loss         | 59.8     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.2e+03   |
# | time/                 |           |
# |    fps                | 2111      |
# |    iterations         | 1200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -0.0242   |
# |    explained_variance | -1.31e-05 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.0226    |
# |    value_loss         | 113       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.2e+03  |
# | time/                 |          |
# |    fps                | 2114     |
# |    iterations         | 1300     |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.0292  |
# |    explained_variance | 2.26e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.32     |
# |    value_loss         | 60.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.2e+03  |
# | time/                 |          |
# |    fps                | 2100     |
# |    iterations         | 1400     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.0237  |
# |    explained_variance | 1.37e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0313   |
# |    value_loss         | 97.8     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.5e+03   |
# | time/                 |           |
# |    fps                | 2079      |
# |    iterations         | 1500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 60000     |
# | train/                |           |
# |    entropy_loss       | -0.00982  |
# |    explained_variance | -2.86e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1499      |
# |    policy_loss        | -0.00217  |
# |    value_loss         | 66.7      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.5e+03  |
# | time/                 |          |
# |    fps                | 2057     |
# |    iterations         | 1600     |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.0289  |
# |    explained_variance | 4.53e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.484   |
# |    value_loss         | 65.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.5e+03  |
# | time/                 |          |
# |    fps                | 2047     |
# |    iterations         | 1700     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.0277  |
# |    explained_variance | 1.25e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0838  |
# |    value_loss         | 109      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.5e+03   |
# | time/                 |           |
# |    fps                | 2052      |
# |    iterations         | 1800      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 72000     |
# | train/                |           |
# |    entropy_loss       | -0.0124   |
# |    explained_variance | -1.67e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1799      |
# |    policy_loss        | 0.0112    |
# |    value_loss         | 92        |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.67e+03  |
# | time/                 |           |
# |    fps                | 2056      |
# |    iterations         | 1900      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 76000     |
# | train/                |           |
# |    entropy_loss       | -0.00714  |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1899      |
# |    policy_loss        | 0.00139   |
# |    value_loss         | 104       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.67e+03 |
# | time/                 |          |
# |    fps                | 2058     |
# |    iterations         | 2000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.00662 |
# |    explained_variance | 4.77e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00266  |
# |    value_loss         | 150      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.67e+03  |
# | time/                 |           |
# |    fps                | 2061      |
# |    iterations         | 2100      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 84000     |
# | train/                |           |
# |    entropy_loss       | -0.0172   |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2099      |
# |    policy_loss        | 0.0586    |
# |    value_loss         | 97.5      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.67e+03  |
# | time/                 |           |
# |    fps                | 2064      |
# |    iterations         | 2200      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -0.00493  |
# |    explained_variance | -1.43e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2199      |
# |    policy_loss        | 0.00142   |
# |    value_loss         | 38.1      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.67e+03  |
# | time/                 |           |
# |    fps                | 2066      |
# |    iterations         | 2300      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 92000     |
# | train/                |           |
# |    entropy_loss       | -0.0154   |
# |    explained_variance | -7.15e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2299      |
# |    policy_loss        | -0.223    |
# |    value_loss         | 122       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.79e+03  |
# | time/                 |           |
# |    fps                | 2069      |
# |    iterations         | 2400      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 96000     |
# | train/                |           |
# |    entropy_loss       | -0.0222   |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2399      |
# |    policy_loss        | -0.575    |
# |    value_loss         | 140       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.79e+03  |
# | time/                 |           |
# |    fps                | 2072      |
# |    iterations         | 2500      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 100000    |
# | train/                |           |
# |    entropy_loss       | -0.00541  |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.00317   |
# |    value_loss         | 100       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.79e+03 |
# | time/                 |          |
# |    fps                | 2075     |
# |    iterations         | 2600     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.00348 |
# |    explained_variance | 7.15e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.00138  |
# |    value_loss         | 26.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.79e+03  |
# | time/                 |           |
# |    fps                | 2077      |
# |    iterations         | 2700      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 108000    |
# | train/                |           |
# |    entropy_loss       | -0.00934  |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2699      |
# |    policy_loss        | 0.0134    |
# |    value_loss         | 118       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.79e+03 |
# | time/                 |          |
# |    fps                | 2079     |
# |    iterations         | 2800     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.00375 |
# |    explained_variance | 4.77e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.00222  |
# |    value_loss         | 56       |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.88e+03  |
# | time/                 |           |
# |    fps                | 2082      |
# |    iterations         | 2900      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 116000    |
# | train/                |           |
# |    entropy_loss       | -0.026    |
# |    explained_variance | -9.54e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2899      |
# |    policy_loss        | -0.095    |
# |    value_loss         | 50.4      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.88e+03 |
# | time/                 |          |
# |    fps                | 2084     |
# |    iterations         | 3000     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.022   |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0626   |
# |    value_loss         | 76.6     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.88e+03  |
# | time/                 |           |
# |    fps                | 2086      |
# |    iterations         | 3100      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 124000    |
# | train/                |           |
# |    entropy_loss       | -0.00459  |
# |    explained_variance | -7.15e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3099      |
# |    policy_loss        | 0.00399   |
# |    value_loss         | 53        |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.88e+03  |
# | time/                 |           |
# |    fps                | 2087      |
# |    iterations         | 3200      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 128000    |
# | train/                |           |
# |    entropy_loss       | -0.0214   |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.152     |
# |    value_loss         | 55.3      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.88e+03  |
# | time/                 |           |
# |    fps                | 2091      |
# |    iterations         | 3300      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 132000    |
# | train/                |           |
# |    entropy_loss       | -0.016    |
# |    explained_variance | -5.96e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3299      |
# |    policy_loss        | 0.0109    |
# |    value_loss         | 77.8      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.94e+03  |
# | time/                 |           |
# |    fps                | 2091      |
# |    iterations         | 3400      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 136000    |
# | train/                |           |
# |    entropy_loss       | -0.00207  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3399      |
# |    policy_loss        | -0.000438 |
# |    value_loss         | 113       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.94e+03  |
# | time/                 |           |
# |    fps                | 2094      |
# |    iterations         | 3500      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 140000    |
# | train/                |           |
# |    entropy_loss       | -0.0079   |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3499      |
# |    policy_loss        | 0.00698   |
# |    value_loss         | 30        |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 3.94e+03  |
# | time/                 |           |
# |    fps                | 2096      |
# |    iterations         | 3600      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 144000    |
# | train/                |           |
# |    entropy_loss       | -0.00625  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3599      |
# |    policy_loss        | 0.013     |
# |    value_loss         | 157       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 3.94e+03 |
# | time/                 |          |
# |    fps                | 2097     |
# |    iterations         | 3700     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.00295 |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.000919 |
# |    value_loss         | 49.2     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4e+03     |
# | time/                 |           |
# |    fps                | 2102      |
# |    iterations         | 3800      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 152000    |
# | train/                |           |
# |    entropy_loss       | -0.0202   |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3799      |
# |    policy_loss        | 0.118     |
# |    value_loss         | 92        |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4e+03     |
# | time/                 |           |
# |    fps                | 2103      |
# |    iterations         | 3900      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 156000    |
# | train/                |           |
# |    entropy_loss       | -0.0252   |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3899      |
# |    policy_loss        | 0.0162    |
# |    value_loss         | 77.7      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4e+03    |
# | time/                 |          |
# |    fps                | 2103     |
# |    iterations         | 4000     |
# |    time_elapsed       | 76       |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -0.0449  |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0173  |
# |    value_loss         | 57.9     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4e+03     |
# | time/                 |           |
# |    fps                | 2104      |
# |    iterations         | 4100      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 164000    |
# | train/                |           |
# |    entropy_loss       | -0.0146   |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4099      |
# |    policy_loss        | -0.123    |
# |    value_loss         | 121       |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4e+03     |
# | time/                 |           |
# |    fps                | 2109      |
# |    iterations         | 4200      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 168000    |
# | train/                |           |
# |    entropy_loss       | -0.00489  |
# |    explained_variance | -4.77e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4199      |
# |    policy_loss        | 0.00332   |
# |    value_loss         | 97.9      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.05e+03 |
# | time/                 |          |
# |    fps                | 2117     |
# |    iterations         | 4300     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 172000   |
# | train/                |          |
# |    entropy_loss       | -0.00161 |
# |    explained_variance | 2.98e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000742 |
# |    value_loss         | 52.1     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4.05e+03  |
# | time/                 |           |
# |    fps                | 2117      |
# |    iterations         | 4400      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 176000    |
# | train/                |           |
# |    entropy_loss       | -0.000895 |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4399      |
# |    policy_loss        | 0.000331  |
# |    value_loss         | 49.7      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.05e+03 |
# | time/                 |          |
# |    fps                | 2117     |
# |    iterations         | 4500     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 180000   |
# | train/                |          |
# |    entropy_loss       | -0.0244  |
# |    explained_variance | 4.17e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0388   |
# |    value_loss         | 23.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.05e+03 |
# | time/                 |          |
# |    fps                | 2118     |
# |    iterations         | 4600     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -0.00189 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.00314  |
# |    value_loss         | 142      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4.05e+03  |
# | time/                 |           |
# |    fps                | 2119      |
# |    iterations         | 4700      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 188000    |
# | train/                |           |
# |    entropy_loss       | -0.000656 |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4699      |
# |    policy_loss        | 0.000271  |
# |    value_loss         | 55.4      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.08e+03 |
# | time/                 |          |
# |    fps                | 2121     |
# |    iterations         | 4800     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.00546 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0125   |
# |    value_loss         | 81.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.08e+03 |
# | time/                 |          |
# |    fps                | 2121     |
# |    iterations         | 4900     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 196000   |
# | train/                |          |
# |    entropy_loss       | -0.00368 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00298 |
# |    value_loss         | 262      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.08e+03 |
# | time/                 |          |
# |    fps                | 2121     |
# |    iterations         | 5000     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -0.00598 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0096   |
# |    value_loss         | 96.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.08e+03 |
# | time/                 |          |
# |    fps                | 2125     |
# |    iterations         | 5100     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 204000   |
# | train/                |          |
# |    entropy_loss       | -0.00102 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.000518 |
# |    value_loss         | 128      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4.11e+03  |
# | time/                 |           |
# |    fps                | 2132      |
# |    iterations         | 5200      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 208000    |
# | train/                |           |
# |    entropy_loss       | -0.00076  |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 5199      |
# |    policy_loss        | -0.000526 |
# |    value_loss         | 87.9      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4.11e+03  |
# | time/                 |           |
# |    fps                | 2132      |
# |    iterations         | 5300      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 212000    |
# | train/                |           |
# |    entropy_loss       | -0.000938 |
# |    explained_variance | 4.17e-07  |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 5299      |
# |    policy_loss        | 0.000268  |
# |    value_loss         | 30.5      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.11e+03 |
# | time/                 |          |
# |    fps                | 2132     |
# |    iterations         | 5400     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -0.00541 |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0474   |
# |    value_loss         | 121      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.11e+03 |
# | time/                 |          |
# |    fps                | 2133     |
# |    iterations         | 5500     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 220000   |
# | train/                |          |
# |    entropy_loss       | -0.0102  |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0609   |
# |    value_loss         | 77.3     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4.11e+03  |
# | time/                 |           |
# |    fps                | 2133      |
# |    iterations         | 5600      |
# |    time_elapsed       | 104       |
# |    total_timesteps    | 224000    |
# | train/                |           |
# |    entropy_loss       | -0.00203  |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 5599      |
# |    policy_loss        | 0.000425  |
# |    value_loss         | 102       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.14e+03 |
# | time/                 |          |
# |    fps                | 2134     |
# |    iterations         | 5700     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 228000   |
# | train/                |          |
# |    entropy_loss       | -0.00552 |
# |    explained_variance | 2.98e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.00664 |
# |    value_loss         | 85.6     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 2.36e+03  |
# |    ep_rew_mean        | 4.14e+03  |
# | time/                 |           |
# |    fps                | 2134      |
# |    iterations         | 5800      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 232000    |
# | train/                |           |
# |    entropy_loss       | -0.0182   |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 5799      |
# |    policy_loss        | 0.00138   |
# |    value_loss         | 40.9      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 2.36e+03 |
# |    ep_rew_mean        | 4.14e+03 |
# | time/                 |          |
# |    fps                | 2134     |
# |    iterations         | 5900     |
# |    time_elapsed       | 110      |
# |    total_timesteps    | 236000   |
# | train/                |          |
# |    entropy_loss       | -0.00267 |
# |    explained_variance | 3.58e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00435  |
# |    value_loss         | 31       |
# ------------------------------------
# A2C training finished.

# %%
# Reset the eval environment
obs = eval_env.reset()
done = False
predicted_labels_ac = []
true_labels_ac = []
instance_uids_ac = []
total_reward_ac = 0

# Turn off exploration for evaluation
while not done:
    action, _ = ac_model.predict(obs, deterministic=True)
    action = action[0]
    obs, reward, done_flags, infos = eval_env.step([action])
    info = infos[0]
    done = done_flags[0]
    total_reward_ac += reward[0]
    predicted_labels_ac.append(action)
    true_labels_ac.append(info['true_label'])
    instance_uids_ac.append(info['instance_uid'])

print(f"A2C Evaluation finished. Total reward: {total_reward_ac}")
# Out:
# A2C Evaluation finished. Total reward: 945.0

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare arrays
predicted_labels_ac = np.array(predicted_labels_ac)
true_labels_ac = np.array(true_labels_ac)

# Compute matrix
cm_ac = confusion_matrix(true_labels_ac, predicted_labels_ac)
TN, FP, FN, TP = cm_ac.ravel() if cm_ac.size == 4 else (0,0,0,0)

print("\n--- A2C Classification Metrics ---")
print(f"TP: {TP}, FP: {FP}, FN: {FN}, TN: {TN}")

# Plot
sns.heatmap(cm_ac, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('A2C Confusion Matrix')
plt.show()
# Out:
# --- A2C Classification Metrics ---
# TP: 84, FP: 18, FN: 14, TN: 475

# %%
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import time
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import io
from PIL import Image
import torch
import os

# Create TensorBoard writer - using the same log dir as during training
# but in a separate "evaluation" subfolder
eval_log_dir = os.path.join(tensorboard_log_dir2, "evaluation", f"a2c_eval_{time.strftime('%Y%m%d-%H%M%S')}")
writer = SummaryWriter(eval_log_dir)
print(f"TensorBoard logs will be saved to: {eval_log_dir}")

# Lists to store data for visualization
rewards_over_time = []
values_over_time = []
action_probs_over_time = []
entropies = []

# Reset the environment for evaluation
obs = eval_env.reset()
done = False
total_reward = 0
predicted_labels = []
true_labels = []
instance_uids = []
episode_steps = 0

# Use deterministic=True to turn off exploration
while not done:
    # For A2C, we can get action probabilities and state values
    with torch.no_grad():
        # Convert observation to tensor
        obs_tensor = torch.FloatTensor(obs).to(ac_model.policy.device)
        
        # Access the policy network and value network directly
        # This is the correct way to access the policy in SB3 A2C
        features = ac_model.policy.extract_features(obs_tensor)
        
        # Get action distribution
        latent_pi, latent_vf = ac_model.policy.mlp_extractor(features)
        action_logits = ac_model.policy.action_net(latent_pi)
        
        # Calculate action probabilities (softmax of logits for discrete actions)
        action_probs = torch.softmax(action_logits, dim=1)
        
        # Get value function prediction
        values = ac_model.policy.value_net(latent_vf)
        
        # Calculate entropy (measure of exploration)
        # For categorical/discrete actions, entropy is -sum(p*log(p))
        log_probs = torch.log_softmax(action_logits, dim=1)
        entropy = -torch.sum(action_probs * log_probs, dim=1).mean().item()
    
    # Store data for visualization
    action_probs_over_time.append(action_probs.cpu().numpy()[0])
    values_over_time.append(values.cpu().numpy()[0][0])
    entropies.append(entropy)
    
    # Predict action (deterministic = use most probable action)
    action, _ = ac_model.predict(obs, deterministic=True)
    action = action[0]
    
    # Log action probabilities
    for i, prob in enumerate(action_probs.cpu().numpy()[0]):
        writer.add_scalar(f'Evaluation/Action_Prob_{i}', prob, episode_steps)
    
    # Log value function and entropy
    writer.add_scalar('Evaluation/Value_Function', values.cpu().numpy()[0][0], episode_steps)
    writer.add_scalar('Evaluation/Policy_Entropy', entropy, episode_steps)
    
    # Step the environment
    obs, reward, done_flags, infos = eval_env.step([action])
    
    # Extract info for the single environment
    info = infos[0]
    done = done_flags[0]
    reward_value = reward[0]  # Reward is also a batch for VecEnv
    total_reward += reward_value
    rewards_over_time.append(reward_value)
    
    # Store results
    predicted_labels.append(action)
    true_labels.append(info['true_label'])
    instance_uids.append(info['instance_uid'])
    
    # Log immediate reward for this step
    writer.add_scalar('Evaluation/Step_Reward', reward_value, episode_steps)
    
    # Log the chosen action
    writer.add_scalar('Evaluation/Action_Taken', action, episode_steps)
    
    episode_steps += 1

# Compute accuracy
accuracy = np.mean(np.array(predicted_labels) == np.array(true_labels))
writer.add_scalar('Evaluation/Accuracy', accuracy, 0)
writer.add_scalar('Evaluation/Total_Reward', total_reward, 0)
writer.add_scalar('Evaluation/Steps', episode_steps, 0)

# Create and log confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))  # Convert to CHW format
writer.add_image('Evaluation/Confusion_Matrix', img_tensor, 0)
plt.close()

# Log detailed classification metrics
class_names = [f"Class_{i}" for i in range(max(max(true_labels), max(predicted_labels)) + 1)]
report = classification_report(true_labels, predicted_labels, target_names=class_names)
writer.add_text('Evaluation/Classification_Report', '```\n' + report + '\n```', 0)

# Add class-wise metrics
for cls in range(len(class_names)):
    # Calculate class precision and recall
    true_positives = sum(1 for true, pred in zip(true_labels, predicted_labels) if true == cls and pred == cls)
    predicted_as_cls = sum(1 for pred in predicted_labels if pred == cls)
    actual_cls = sum(1 for true in true_labels if true == cls)
    
    precision = true_positives / predicted_as_cls if predicted_as_cls > 0 else 0
    recall = true_positives / actual_cls if actual_cls > 0 else 0
    
    writer.add_scalar(f'Evaluation/Class_{cls}_Precision', precision, 0)
    writer.add_scalar(f'Evaluation/Class_{cls}_Recall', recall, 0)

# Create a plot of rewards and value function over time
plt.figure(figsize=(12, 8))

# Plot rewards
plt.subplot(2, 2, 1)
plt.plot(range(len(rewards_over_time)), rewards_over_time)
plt.xlabel('Step')
plt.ylabel('Step Reward')
plt.title('Rewards Per Step')
plt.grid(True)

# Plot cumulative rewards
plt.subplot(2, 2, 2)
cumulative_rewards = np.cumsum(rewards_over_time)
plt.plot(range(len(cumulative_rewards)), cumulative_rewards)
plt.xlabel('Step')
plt.ylabel('Cumulative Reward')
plt.title('Cumulative Reward')
plt.grid(True)

# Plot value function estimates
plt.subplot(2, 2, 3)
plt.plot(range(len(values_over_time)), values_over_time)
plt.xlabel('Step')
plt.ylabel('Value Estimate')
plt.title('Value Function Estimates')
plt.grid(True)

# Plot advantage (reward - value) to see if value function is accurate
plt.subplot(2, 2, 4)
advantages = [r - v for r, v in zip(rewards_over_time, values_over_time)]
plt.plot(range(len(advantages)), advantages)
plt.xlabel('Step')
plt.ylabel('Advantage (Reward - Value)')
plt.title('Advantage Estimates')
plt.grid(True)

plt.tight_layout()

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Reward_Value_Analysis', img_tensor, 0)
plt.close()

# Visualize action probabilities over time (policy evolution)
plt.figure(figsize=(12, 6))

# Plot action probabilities
plt.subplot(1, 2, 1)
action_probs_array = np.array(action_probs_over_time)
for i in range(action_probs_array.shape[1]):
    plt.plot(range(len(action_probs_over_time)), action_probs_array[:, i], label=f'Action {i}')
plt.xlabel('Step')
plt.ylabel('Action Probability')
plt.title('Action Probabilities Over Time')
plt.legend()
plt.grid(True)

# Plot entropy
plt.subplot(1, 2, 2)
plt.plot(range(len(entropies)), entropies)
plt.xlabel('Step')
plt.ylabel('Entropy')
plt.title('Policy Entropy Over Time')
plt.grid(True)

plt.tight_layout()

# Convert plot to image and log to TensorBoard
buf = io.BytesIO()
plt.savefig(buf, format='png')
buf.seek(0)
img = Image.open(buf)
img_tensor = np.array(img).transpose((2, 0, 1))
writer.add_image('Evaluation/Policy_Analysis', img_tensor, 0)
plt.close()

# Close the writer
writer.close()

print(f"Evaluation finished. Total reward: {total_reward}")
print(f"Accuracy: {accuracy:.4f}")
print(f"TensorBoard logs saved to {eval_log_dir}")
print("To view TensorBoard visualization, run:")
print(f"tensorboard --logdir={tensorboard_log_dir}")  # Point to the parent log dir to see both training and evaluation
# Out:
# TensorBoard logs will be saved to: ./a2c_fraud_tb/evaluation/a2c_eval_20260227-122352
# Evaluation finished. Total reward: 945.0
# Accuracy: 0.9459
# TensorBoard logs saved to ./a2c_fraud_tb/evaluation/a2c_eval_20260227-122352
# To view TensorBoard visualization, run:
# tensorboard --logdir=./dqn_fraud_tb/

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy_ac  = accuracy_score(true_labels_ac, predicted_labels_ac)
precision_ac = precision_score(true_labels_ac, predicted_labels_ac, zero_division=0)
recall_ac    = recall_score(true_labels_ac, predicted_labels_ac, zero_division=0)
f1_ac        = f1_score(true_labels_ac, predicted_labels_ac, zero_division=0)

print(f"A2C Accuracy: {accuracy_ac:.4f}")
print(f"A2C Precision (Class 1 - Fraud): {precision_ac:.4f}")
print(f"A2C Recall    (Class 1 - Fraud): {recall_ac:.4f}")
print(f"A2C F1 Score  (Class 1 - Fraud): {f1_ac:.4f}")
# Out:
# A2C Accuracy: 0.9459
# A2C Precision (Class 1 - Fraud): 0.8235
# A2C Recall    (Class 1 - Fraud): 0.8571
# A2C F1 Score  (Class 1 - Fraud): 0.8400

# %%
# 1. Choose a save path (no need to add “.zip”—SB3 will append it for you)
save_path = "models/a2c_fraud_model"

# 2. Save your A2C model
ac_model.save(save_path)

# 3. Confirm it on screen
print(f"A2C model saved to {save_path}.zip")
# Out:
# A2C model saved to models/a2c_fraud_model.zip
